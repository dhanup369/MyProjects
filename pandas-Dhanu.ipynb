# %% [markdown]
# <h1> Panda Tutotial-Dhanu </h1>

# %%
import pandas

# %%
pandas.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 3.6.1.final.0
# python-bits: 64
# OS: Darwin
# OS-release: 17.5.0
# machine: x86_64
# processor: i386
# byteorder: little
# LC_ALL: None
# LANG: en_US.UTF-8
# LOCALE: en_US.UTF-8
#
# pandas: 0.20.1
# pytest: 3.0.7
# pip: 10.0.1
# setuptools: 27.2.0
# Cython: 0.25.2
# numpy: 1.12.1
# scipy: 0.19.0
# xarray: None
# IPython: 5.3.0
# sphinx: 1.5.6
# patsy: 0.4.1
# dateutil: 2.6.0
# pytz: 2017.2
# blosc: None
# bottleneck: 1.2.1
# tables: 3.3.0
# numexpr: 2.6.2
# feather: None
# matplotlib: 2.0.2
# openpyxl: 2.4.7
# xlrd: 1.0.0
# xlwt: 1.2.0
# xlsxwriter: 0.9.6
# lxml: 3.7.3
# bs4: 4.6.0
# html5lib: 0.999
# sqlalchemy: 1.1.9
# pymysql: None
# psycopg2: None
# jinja2: 2.9.6
# s3fs: None
# pandas_gbq: None
# pandas_datareader: 0.5.0

# %%
pandas.__version__
# Out:
# '0.20.1'

# %%
import pandas as pd
pd.__version__
# Out:
# '0.20.1'

# %% [markdown]
# <h3>pd.press tab will show all the functions available ,and to see the doc string pd.(function name)? for example pd.show_versions?
# pd.sho+tab will auto fill the function names</h3>

# %%
pd.Series?

# %% [markdown]
# <h2>A dataframe is a two dimensional array,Jupyter notebook displays first and last 30 rows of a dataframe</h2>

# %%
df=pd.read_csv("olympics.csv" ,skiprows=4)#Observations start from row 5 in the original csv file
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df['City'].head()
# Out:
# 0    Athens
# 1    Athens
# 2    Athens
# 3    Athens
# 4    Athens
# Name: City, dtype: object

# %%
df["City"].head()
# Out:
# 0    Athens
# 1    Athens
# 2    Athens
# 3    Athens
# 4    Athens
# Name: City, dtype: object

# %%
df.City.head()#Dot notation dosent work if theres a space between column name like "City Name"
# Out:
# 0    Athens
# 1    Athens
# 2    Athens
# 3    Athens
# 4    Athens
# Name: City, dtype: object

# %%
#More columns -list of column names 
df[["City","Edition","Sport"]].head()
# Out:
#      City  Edition     Sport
# 0  Athens     1896  Aquatics
# 1  Athens     1896  Aquatics
# 2  Athens     1896  Aquatics
# 3  Athens     1896  Aquatics
# 4  Athens     1896  Aquatics

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.City)#Type of single column will be a series
# Out:
# pandas.core.series.Series

# %%
type(df[["City","Edition","Sport"]])#Type of multiple columns will be a data frame
# Out:
# pandas.core.frame.DataFrame

# %%
df['NOC'].head()
# Out:
# 0    HUN
# 1    AUT
# 2    GRE
# 3    GRE
# 4    GRE
# Name: NOC, dtype: object

# %%
type(df['NOC'].head())
# Out:
# pandas.core.series.Series

# %%
df[["Edition","City","Athlete","Medal"]].head()
# Out:
#    Edition    City             Athlete   Medal
# 0     1896  Athens       HAJOS, Alfred    Gold
# 1     1896  Athens    HERSCHMANN, Otto  Silver
# 2     1896  Athens   DRIVAS, Dimitrios  Bronze
# 3     1896  Athens  MALOKINIS, Ioannis    Gold
# 4     1896  Athens  CHASAPIS, Spiridon  Silver

# %% [markdown]
# <h3>input files:pd.read_csv(),pd.read_excel(),pd.read_json(),pd.read_sql_table()</h3>

# %% [markdown]
# pd.read_csv(shift+tab)will show the method and press tab 4 times will display the entire docstring

# %%
df.shape #Gives the dimensions of the data frame as tuple
# Out:
# (29216, 10)

# %%
df.shape[0]
# Out:
# 29216

# %%
df.shape[1]
# Out:
# 10

# %% [markdown]
# <h3>df.info()</h3> provides a summary of the data frame including the number of entries, the data type, and the number of non-null entries for each series in the data frame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29216 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# <h3>value_counts()</h3> It returns a series object, counting all the unique values. There are two things in particular to be aware of value_counts. As this is returning a count of the unique values, the first value is the most frequently occurring element. The second, the second most frequently occurring element and so on. This order can be reversed by just setting the ascending flag to True.
# Dropna, one of the parameters within the value_counts is True by default and you will not get a count of the na values. The na values are the missing data values. If your data set has a significant number of na values, this can be misleading and you can turn this feature off by setting dropna to False.

# %%
df["City"].value_counts()
# Out:
# Athens                   2149
# Los Angeles              2074
# Beijing                  2042
# Sydney                   2015
# Atlanta                  1859
# Barcelona                1705
# London                   1618
# Seoul                    1546
# Paris                    1396
# Moscow                   1387
# Montreal                 1305
# Antwerp                  1298
# Munich                   1185
# Mexico                   1031
# Tokyo                    1010
# Helsinki                  889
# Melbourne / Stockholm     885
# Stockholm                 885
# Rome                      882
# Berlin                    875
# Amsterdam                 710
# St Louis                  470
# Name: City, dtype: int64

# %%
df.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %% [markdown]
# <h3>Sort_values()</h3> sorts the values in a series. As axis is equal to zero, you are sorting along the column and in ascending order by default. So if you visualize a series as being a single column, you are sorting the contents of that column in ascending order. By default, the NaNs, or missing data, are put right at the end. Sort_values(), when used in conjunction with a DataFrame, is particularly useful as you can sort multiple series in ascending and descending order.

# %%
ath=df.Athlete.sort_values()
ath.head()
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
# Name: Athlete, dtype: object

# %%
df.sort_values(by=["Edition","Athlete"]).head()
# Out:
#        City  Edition       Sport    Discipline                   Athlete  NOC  \
# 7    Athens     1896    Aquatics      Swimming          ANDREOU, Joannis  GRE
# 82   Athens     1896  Gymnastics   Artistic G.  ANDRIAKOPOULOS, Nicolaos  GRE
# 110  Athens     1896  Gymnastics   Artistic G.  ANDRIAKOPOULOS, Nicolaos  GRE
# 111  Athens     1896  Gymnastics   Artistic G.    ATHANASOPOULOS, Spyros  GRE
# 48   Athens     1896     Cycling  Cycling Road            BATTEL, Edward  GBR
#
#     Gender                 Event Event_gender   Medal
# 7      Men       1200m freestyle            M  Silver
# 82     Men         rope climbing            M    Gold
# 110    Men   team, parallel bars            M  Silver
# 111    Men   team, parallel bars            M  Silver
# 48     Men  individual road race            M  Bronze

# %% [markdown]
# <h3>Boolean indexing.</h3> Boolean vectors or conditions can be used to filter data. Based on a condition, pass series of true and false values to a series or data frame to select and display the rules where the series has true values. Instead of using and, or, or not, as with most programming languages, you can use the following symbols instead. Remember that if you have more than one condition, or Boolean vector, this must be grouped in brackets or parentheses.
#
# This is to ensure that the order of operations is carried out correctly.(AND = & , OR = | , NOT =~)

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df.Medal=="Gold"
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
# 6         True
# 7        False
# 8        False
# 9         True
# 10       False
# 11       False
# 12       False
# 13        True
# 14       False
# 15        True
# 16       False
# 17       False
# 18        True
# 19       False
# 20       False
# 21        True
# 22       False
# 23       False
# 24        True
# 25       False
# 26       False
# 27        True
# 28       False
# 29        True
#          ...
# 29186    False
# 29187     True
# 29188    False
# 29189    False
# 29190    False
# 29191     True
# 29192    False
# 29193    False
# 29194    False
# 29195     True
# 29196    False
# 29197    False
# 29198    False
# 29199     True
# 29200    False
# 29201    False
# 29202    False
# 29203     True
# 29204    False
# 29205    False
# 29206     True
# 29207    False
# 29208    False
# 29209    False
# 29210     True
# 29211    False
# 29212    False
# 29213    False
# 29214     True
# 29215    False
# Name: Medal, Length: 29216, dtype: bool

# %%
df[df.Medal=="Gold"].head()
# Out:
#       City  Edition      Sport Discipline             Athlete  NOC Gender  \
# 0   Athens     1896   Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 3   Athens     1896   Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 6   Athens     1896   Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 9   Athens     1896   Aquatics   Swimming       NEUMANN, Paul  AUT    Men
# 13  Athens     1896  Athletics  Athletics       BURKE, Thomas  USA    Men
#
#                          Event Event_gender Medal
# 0               100m freestyle            M  Gold
# 3   100m freestyle for sailors            M  Gold
# 6              1200m freestyle            M  Gold
# 9               400m freestyle            M  Gold
# 13                        100m            M  Gold

# %%
df[df.Medal=="Gold"].Athlete.sort_values().head()
# Out:
# 651                  AABYE, Edgar
# 7716     AALTONEN, Paavo Johannes
# 7730     AALTONEN, Paavo Johannes
# 7773     AALTONEN, Paavo Johannes
# 28460            AAMODT, Ragnhild
# Name: Athlete, dtype: object

# %%
df[(df.Medal=="Gold") & (df.Gender=='Women')].head()
# Out:
#          City  Edition    Sport Discipline                Athlete  NOC Gender  \
# 417     Paris     1900     Golf       Golf  ABBOTT, Margaret Ives  USA  Women
# 641     Paris     1900   Tennis     Tennis      COOPER, Charlotte  GBR  Women
# 649     Paris     1900   Tennis     Tennis      COOPER, Charlotte  GBR  Women
# 710  St Louis     1904  Archery    Archery  HOWELL, Matilda Scott  USA  Women
# 713  St Louis     1904  Archery    Archery  HOWELL, Matilda Scott  USA  Women
#
#                                        Event Event_gender Medal
# 417                               individual            W  Gold
# 641                            mixed doubles            X  Gold
# 649                                  singles            W  Gold
# 710  double columbia round (50y - 40y - 30y)            W  Gold
# 713        double national round (60y - 50y)            W  Gold

# %% [markdown]
#  <h3>String handling</h3> Generally have names matching the equivalent scaler built in string methods that are available in Python. These are available under the str attribute. Using the str attribute, you have access to several common string methods, such as contains, startswith, isnumeric and so on. [Series.str.contains(),Series.str.startswith(),Series.str.isnumeric()]

# %%
df.Athlete.str.contains('Florence').head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Athlete, dtype: bool

# %%
df[df.Athlete.str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# 1848                   SYERS, Florence  GBR  Women                   pairs
# 4173                  BARKER, Florence  GBR  Women  4x100m freestyle relay
# 8162        FOULDS-PAUL, June Florence  GBR  Women            4x100m relay
# 9060        FOULDS-PAUL, June Florence  GBR  Women            4x100m relay
# 10849  AMOORE-POLLOCK, Judith Florence  AUS  Women                    400m
# 16817        GRIFFITH-JOYNER, Florence  USA  Women                    200m
# 18287        GRIFFITH-JOYNER, Florence  USA  Women                    100m
# 18305        GRIFFITH-JOYNER, Florence  USA  Women                    200m
# 18347        GRIFFITH-JOYNER, Florence  USA  Women            4x100m relay
# 18374        GRIFFITH-JOYNER, Florence  USA  Women            4x400m relay
#
#       Event_gender   Medal
# 1843             W    Gold
# 1848             X  Bronze
# 4173             W  Silver
# 8162             W  Bronze
# 9060             W  Silver
# 10849            W  Bronze
# 16817            W  Silver
# 18287            W    Gold
# 18305            W    Gold
# 18347            W    Gold
# 18374            W  Silver

# %%
df[df.Athlete.str.contains('Jesse')]
# Out:
#                         City  Edition       Sport     Discipline  \
# 1522                  London     1908      Hockey         Hockey
# 1773                  London     1908    Shooting       Shooting
# 6427                  Berlin     1936   Athletics      Athletics
# 6439                  Berlin     1936   Athletics      Athletics
# 6456                  Berlin     1936   Athletics      Athletics
# 6523                  Berlin     1936   Athletics      Athletics
# 7444                  London     1948  Basketball     Basketball
# 9070   Melbourne / Stockholm     1956   Athletics      Athletics
# 11462                  Tokyo     1964      Rowing         Rowing
# 13113                 Munich     1972      Boxing         Boxing
# 26519                 Athens     2004      Hockey         Hockey
# 27479                Beijing     2008    Aquatics     Water polo
# 28065                Beijing     2008     Cycling  Cycling Track
#
#                             Athlete  NOC Gender                       Event  \
# 1522             WOOD, Harvey Jesse  GBR    Men                      hockey
# 1773      WALLINGFORD, Jesse Alfred  GBR    Men       50y army pistol, team
# 6427                   OWENS, Jesse  USA    Men                        100m
# 6439                   OWENS, Jesse  USA    Men                        200m
# 6456                   OWENS, Jesse  USA    Men                4x100m relay
# 6523                   OWENS, Jesse  USA    Men                   long jump
# 7444   RENICK, John (Jesse) Bernard  USA    Men                  basketball
# 9070        MASHBURN, Jesse William  USA    Men                4x400m relay
# 11462             JAMES, John Jesse  GBR    Men  four without coxswain (4-)
# 13113          VALDEZ, John (Jesse)  USA    Men  63.5 - 67kg (welterweight)
# 26519                 MAHIEU, Jesse  NED    Men                      hockey
# 27479                  SMITH, Jesse  USA    Men                  water polo
# 28065                SERGENT, Jesse  NZL    Men        Team Pursuit (4000m)
#
#       Event_gender   Medal
# 1522             M    Gold
# 1773             M  Bronze
# 6427             M    Gold
# 6439             M    Gold
# 6456             M    Gold
# 6523             M    Gold
# 7444             M    Gold
# 9070             M    Gold
# 11462            M  Silver
# 13113            M  Bronze
# 26519            M  Silver
# 27479            M  Silver
# 28065            M  Bronze

# %%
jo=df[df.Athlete=='OWENS, Jesse']
jo
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
jo.Event.value_counts()
# Out:
# 4x100m relay    1
# 200m            1
# long jump       1
# 100m            1
# Name: Event, dtype: int64

# %%
ch=df[(df.Sport=="Badminton")&(df.Gender=="Men")&(df.Event=="singles")&(df.Medal=="Gold")]
ch
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 27741    Beijing     2008  Badminton  Badminton                 LIN, Dan  CHN
#
#       Gender    Event Event_gender Medal
# 20045    Men  singles            M  Gold
# 21787    Men  singles            M  Gold
# 23717    Men  singles            M  Gold
# 25734    Men  singles            M  Gold
# 27741    Men  singles            M  Gold

# %%
ch.sort_values(by="Athlete")
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27741    Beijing     2008  Badminton  Badminton                 LIN, Dan  CHN
#
#       Gender    Event Event_gender Medal
# 20045    Men  singles            M  Gold
# 25734    Men  singles            M  Gold
# 21787    Men  singles            M  Gold
# 23717    Men  singles            M  Gold
# 27741    Men  singles            M  Gold

# %%
co=df[( df.Edition >=1984)]
co.head()
# Out:
#               City  Edition     Sport Discipline                      Athlete  \
# 16592  Los Angeles     1984  Aquatics     Diving               LI, Kong-Zheng
# 16593  Los Angeles     1984  Aquatics     Diving            LOUGANIS, Gregory
# 16594  Los Angeles     1984  Aquatics     Diving            KIMBALL, Bruce D.
# 16595  Los Angeles     1984  Aquatics     Diving  WYLAND-WILLIAMS, Wendy Lian
# 16596  Los Angeles     1984  Aquatics     Diving                ZHOU, Ji-Hong
#
#        NOC Gender         Event Event_gender   Medal
# 16592  CHN    Men  10m platform            M  Bronze
# 16593  USA    Men  10m platform            M    Gold
# 16594  USA    Men  10m platform            M  Silver
# 16595  USA  Women  10m platform            W  Bronze
# 16596  CHN  Women  10m platform            W    Gold

# %%
co.NOC.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %%
f=df[(df.Gender=="Men")&(df.Medal=="Gold")&(df.Event=="100m")].sort_values(by="Edition",ascending=False)[["City","Edition","Athlete","NOC"]]
f.head()
# Out:
#             City  Edition            Athlete  NOC
# 27552    Beijing     2008        BOLT, Usain  JAM
# 25539     Athens     2004     GATLIN, Justin  USA
# 23521     Sydney     2000    GREENE, Maurice  USA
# 21598    Atlanta     1996    BAILEY, Donovan  CAN
# 19859  Barcelona     1992  CHRISTIE, Linford  GBR

# %%
ls
# Out:
# ExerciseFiles/                  netflix_ratings.csv
# README.md                       netflix_ratings.py
# Udemy.py                        new.csv
# Virtual_environment_python.txt  olympics.csv*
# __pycache__/                    output.csv
# accounting.csv                  pandas-Dhanu.ipynb
# accounting.py                   pandas-cheat-sheet.pdf
# candy.py                        pie.py
# cereal.csv                      roster.csv
# cereal.py                       roster.py
# cereal_bonus.csv                simple.py
# cerealbonus.py                  txtread.py
# csvwrite.csv                    udemy.csv
# csvwrite.py                     web_starter.csv
# csvwriter.py                    weddinginvite.py
# fileread.py                     wrestler.csv
# hobbybook.py                    wrestler.py
# mean.py

# %% [markdown]
# <h3>Basic Plotting:</h3>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
#  One of the features of the IPython kernel
# is the ability to display plots that are the output of
# running code cells. The IPython kernel works with
# the Matplotlib Plotting Library to provide this functionality.
# To set this up, you must execute that second line, matplotlib
# inline and also known as a merger command. With the
# Matplotlib inline backend, the output of the plotting commands
# is displayed inline, within the Jupiter Notebook, directly below
# the code cell that produced it. The resulting plots will then also be
# stored in the notebook document.

# %% [markdown]
# <h3>Plots:</h3>
# plot():<br>
# Plot(kind='line')-Tracking changes over a period of time(Default)<br>
# Plot(kind='bar')-Best for comparing between different groups<br>
# Plot(kind='barh')-Horizontal bar graph when changes are too large <br>
# Plot(kind='pie')-Best for comparing parts of whole

# %%
pl=df[df.Edition==1896]
pl.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
pl.Sport.value_counts().plot(kind='pie')#If we add semicolon we can remove the line shown abbove the plot.

# %%
pl.Sport.value_counts().plot(kind='pie');

# %%
pl.Sport.value_counts().plot(kind='bar',color='red');#to change the color

# %%
pl.Sport.value_counts().plot(kind='barh',figsize=(7,5));#To chage the figure size ,width and height in a tuple

# %%
pl.Sport.value_counts().plot(kind='line');

# %%
pl.Sport.value_counts().plot(kind='line',figsize=(10,3));

# %% [markdown]
# <h3>Color Maps:</h3>Colormaps are included with Matplotlib. The idea behind choosing a cool colormap, is to find a good representation of your data. It there an intuitive color scheme for the data? For example gold, silver, and bronze for medal winners. Blue for male, pink for female? There are three classes of colormaps.<br> The sequential,the diverging, and the qualitative. The sequential should be used for representing information that has ordering. There is a change in lightness, often over a single hue.Diverging is to be used when the information being plotted deviates around a middle value. Here there are often two different colors being used. And finally, the qualitative class is used to represent information which does not have any ordering or relationship, and is often miscellaneous colors

# %%
pl.Sport.value_counts().plot(kind='pie',colormap='Pastel1');

# %% [markdown]
# Seaborn Basic Plotting. Seaborn is a visualization library based on Matplotlib. One of the reasons to use Seaborn is that it produces beautiful statistical plots. It is very important to realize that Seaborn is a complement and not a substitute to Matplotlib. Now one of the advantages again with using Seaborn is that it works very well with pandas. Seaborn has an excellent examples gallery that provides plots on the website, and if you click on any of the plots, it provides the code to generate that plot.
#
# Seaborn, as with Matplotlib, has methods for bar plots, histograms and pie charts. Let's take a look at an example of one of the methods, countplot. Countplot has very similar parameters to Matplotlib. The data parameter for countplot is where you provide the DataFrame or the source for the data. The hue is for the categorical variables. A categorical variable is one that can only take a fixed number of values.
#
# In the Olympics dataset, we have a couple of examples of categorical variables. There are only a limited number of sports, the gender is either male or female, and medals are gold, silver or bronze. The hue allows you to specify a categorical variable in a different color. The order parameter allows you to determine the sequence of the categorical variables. And finally, the palette parameter allows you to specify colors for the different levels of the hue variable.
#
# So when would you use Seaborn versus Matplotlib? If you're running a couple of scripts, then Matplotlib with pyplot is easy to use and great for bar charts, pie charts and so on. If you're looking to write short scripts to deal with things like categorical data, or more advanced statistical plots, or creating other kinds of plots such as heatmaps, then Seaborn is going to be your choice.

# %%
import seaborn as sns
seaborn.countplot?
# Out:
# Object `seaborn.countplot` not found.

# %%
sns.countplot(x='Medal',data=df)#Medals won by both men and woman

# %%
sns.countplot(x='Medal',data=df,hue="Gender")

# %%
china=df[(df.NOC=='CHN')&(df.Edition==2008)&(df.City=="Beijing")]
china.head()
# Out:
#           City  Edition     Sport Discipline       Athlete  NOC Gender  \
# 27176  Beijing     2008  Aquatics     Diving   ZHOU, Luxin  CHN    Men
# 27177  Beijing     2008  Aquatics     Diving     WANG, Xin  CHN  Women
# 27178  Beijing     2008  Aquatics     Diving  CHEN, Ruolin  CHN  Women
# 27180  Beijing     2008  Aquatics     Diving      QIN, Kai  CHN    Men
# 27181  Beijing     2008  Aquatics     Diving     HE, Chong  CHN    Men
#
#                 Event Event_gender   Medal
# 27176    10m platform            M  Silver
# 27177    10m platform            W  Bronze
# 27178    10m platform            W    Gold
# 27180  3m springboard            M  Bronze
# 27181  3m springboard            M    Gold

# %%
sns.countplot(x='Medal',data=china)

# %%
china.Medal.value_counts().plot(kind='bar',colormap='summer');

# %%
sns.countplot(x='Medal',data=china,hue='Gender')

# %%
sns.countplot(x='Medal',data=china,hue='Gender', palette='bwr');

# %%
sns.countplot(x='Medal',data=china,hue='Gender', palette='bwr',order=["Gold","Silver","Bronze"])

# %%
china.Gender.value_counts().plot(kind='bar',figsize=(6,4));

# %%
china.Gender.value_counts().plot(kind='bar',color=tuple(['b','g']))

# %% [markdown]
# <h3>Indexing:<h3>

# %%
df.set_index('Athlete')#This willnot actually change the original table until we set 'inplace=True'
# Out:
#                                 City  Edition      Sport       Discipline  \
# Athlete
# HAJOS, Alfred                 Athens     1896   Aquatics         Swimming
# HERSCHMANN, Otto              Athens     1896   Aquatics         Swimming
# DRIVAS, Dimitrios             Athens     1896   Aquatics         Swimming
# MALOKINIS, Ioannis            Athens     1896   Aquatics         Swimming
# CHASAPIS, Spiridon            Athens     1896   Aquatics         Swimming
# CHOROPHAS, Efstathios         Athens     1896   Aquatics         Swimming
# HAJOS, Alfred                 Athens     1896   Aquatics         Swimming
# ANDREOU, Joannis              Athens     1896   Aquatics         Swimming
# CHOROPHAS, Efstathios         Athens     1896   Aquatics         Swimming
# NEUMANN, Paul                 Athens     1896   Aquatics         Swimming
# PEPANOS, Antonios             Athens     1896   Aquatics         Swimming
# LANE, Francis                 Athens     1896  Athletics        Athletics
# SZOKOLYI, Alajos              Athens     1896  Athletics        Athletics
# BURKE, Thomas                 Athens     1896  Athletics        Athletics
# HOFMANN, Fritz                Athens     1896  Athletics        Athletics
# CURTIS, Thomas                Athens     1896  Athletics        Athletics
# GOULDING, Grantley            Athens     1896  Athletics        Athletics
# LERMUSIAUX, Albin             Athens     1896  Athletics        Athletics
# FLACK, Edwin                  Athens     1896  Athletics        Athletics
# BLAKE, Arthur                 Athens     1896  Athletics        Athletics
# GMELIN, Charles               Athens     1896  Athletics        Athletics
# BURKE, Thomas                 Athens     1896  Athletics        Athletics
# JAMISON, Herbert              Athens     1896  Athletics        Athletics
# GOLEMIS, Dimitrios            Athens     1896  Athletics        Athletics
# FLACK, Edwin                  Athens     1896  Athletics        Athletics
# DANI, Nandor                  Athens     1896  Athletics        Athletics
# VERSIS, Sotirios              Athens     1896  Athletics        Athletics
# GARRETT, Robert               Athens     1896  Athletics        Athletics
# PARASKEVOPOULOS, Panagiotis   Athens     1896  Athletics        Athletics
# CLARK, Ellery                 Athens     1896  Athletics        Athletics
# ...                              ...      ...        ...              ...
# MUTALIMOV, Marid             Beijing     2008  Wrestling  Wrestling Free.
# TAYMAZOV, Artur              Beijing     2008  Wrestling  Wrestling Free.
# AKHMEDOV, Bakhtiyar          Beijing     2008  Wrestling  Wrestling Free.
# AMOYAN, Roman                Beijing     2008  Wrestling  Wrestling Gre-R
# PARK, Eun-Chul               Beijing     2008  Wrestling  Wrestling Gre-R
# MANKIEV, Nazyr               Beijing     2008  Wrestling  Wrestling Gre-R
# BAYRAMOV, Rovshan            Beijing     2008  Wrestling  Wrestling Gre-R
# TENGIZBAYEV, Nurbakyt        Beijing     2008  Wrestling  Wrestling Gre-R
# TIUMENBAEV, Ruslan           Beijing     2008  Wrestling  Wrestling Gre-R
# ALBIEV, Islam-Beka           Beijing     2008  Wrestling  Wrestling Gre-R
# RAHIMOV, Vitaliy             Beijing     2008  Wrestling  Wrestling Gre-R
# SIAMIONAU, Mikhail           Beijing     2008  Wrestling  Wrestling Gre-R
# VARDANYAN, Armen             Beijing     2008  Wrestling  Wrestling Gre-R
# GUENOT, Steeve               Beijing     2008  Wrestling  Wrestling Gre-R
# BEGALIEV, Kanatbek           Beijing     2008  Wrestling  Wrestling Gre-R
# GUENOT, Christophe           Beijing     2008  Wrestling  Wrestling Gre-R
# YANAKIEV, Yavor              Beijing     2008  Wrestling  Wrestling Gre-R
# KVIRKELIA, Manuchar          Beijing     2008  Wrestling  Wrestling Gre-R
# CHANG, Yongxiang             Beijing     2008  Wrestling  Wrestling Gre-R
# AVLUCA, Nazmi                Beijing     2008  Wrestling  Wrestling Gre-R
# MINGUZZI, Andrea             Beijing     2008  Wrestling  Wrestling Gre-R
# FODOR, Zoltan                Beijing     2008  Wrestling  Wrestling Gre-R
# MAMBETOV, Asset              Beijing     2008  Wrestling  Wrestling Gre-R
# WHEELER, Adam                Beijing     2008  Wrestling  Wrestling Gre-R
# KHUSHTOV, Aslanbek           Beijing     2008  Wrestling  Wrestling Gre-R
# ENGLICH, Mirko               Beijing     2008  Wrestling  Wrestling Gre-R
# MIZGAITIS, Mindaugas         Beijing     2008  Wrestling  Wrestling Gre-R
# PATRIKEEV, Yuri              Beijing     2008  Wrestling  Wrestling Gre-R
# LOPEZ, Mijain                Beijing     2008  Wrestling  Wrestling Gre-R
# BAROEV, Khasan               Beijing     2008  Wrestling  Wrestling Gre-R
#
#                              NOC Gender                       Event  \
# Athlete
# HAJOS, Alfred                HUN    Men              100m freestyle
# HERSCHMANN, Otto             AUT    Men              100m freestyle
# DRIVAS, Dimitrios            GRE    Men  100m freestyle for sailors
# MALOKINIS, Ioannis           GRE    Men  100m freestyle for sailors
# CHASAPIS, Spiridon           GRE    Men  100m freestyle for sailors
# CHOROPHAS, Efstathios        GRE    Men             1200m freestyle
# HAJOS, Alfred                HUN    Men             1200m freestyle
# ANDREOU, Joannis             GRE    Men             1200m freestyle
# CHOROPHAS, Efstathios        GRE    Men              400m freestyle
# NEUMANN, Paul                AUT    Men              400m freestyle
# PEPANOS, Antonios            GRE    Men              400m freestyle
# LANE, Francis                USA    Men                        100m
# SZOKOLYI, Alajos             HUN    Men                        100m
# BURKE, Thomas                USA    Men                        100m
# HOFMANN, Fritz               GER    Men                        100m
# CURTIS, Thomas               USA    Men                110m hurdles
# GOULDING, Grantley           GBR    Men                110m hurdles
# LERMUSIAUX, Albin            FRA    Men                       1500m
# FLACK, Edwin                 AUS    Men                       1500m
# BLAKE, Arthur                USA    Men                       1500m
# GMELIN, Charles              GBR    Men                        400m
# BURKE, Thomas                USA    Men                        400m
# JAMISON, Herbert             USA    Men                        400m
# GOLEMIS, Dimitrios           GRE    Men                        800m
# FLACK, Edwin                 AUS    Men                        800m
# DANI, Nandor                 HUN    Men                        800m
# VERSIS, Sotirios             GRE    Men                discus throw
# GARRETT, Robert              USA    Men                discus throw
# PARASKEVOPOULOS, Panagiotis  GRE    Men                discus throw
# CLARK, Ellery                USA    Men                   high jump
# ...                          ...    ...                         ...
# MUTALIMOV, Marid             KAZ    Men                  96 - 120kg
# TAYMAZOV, Artur              UZB    Men                  96 - 120kg
# AKHMEDOV, Bakhtiyar          RUS    Men                  96 - 120kg
# AMOYAN, Roman                ARM    Men                      - 55kg
# PARK, Eun-Chul               KOR    Men                      - 55kg
# MANKIEV, Nazyr               RUS    Men                      - 55kg
# BAYRAMOV, Rovshan            AZE    Men                      - 55kg
# TENGIZBAYEV, Nurbakyt        KAZ    Men                   55 - 60kg
# TIUMENBAEV, Ruslan           KGZ    Men                   55 - 60kg
# ALBIEV, Islam-Beka           RUS    Men                   55 - 60kg
# RAHIMOV, Vitaliy             AZE    Men                   55 - 60kg
# SIAMIONAU, Mikhail           BLR    Men                   60 - 66kg
# VARDANYAN, Armen             UKR    Men                   60 - 66kg
# GUENOT, Steeve               FRA    Men                   60 - 66kg
# BEGALIEV, Kanatbek           KGZ    Men                   60 - 66kg
# GUENOT, Christophe           FRA    Men                   66 - 74kg
# YANAKIEV, Yavor              BUL    Men                   66 - 74kg
# KVIRKELIA, Manuchar          GEO    Men                   66 - 74kg
# CHANG, Yongxiang             CHN    Men                   66 - 74kg
# AVLUCA, Nazmi                TUR    Men                   74 - 84kg
# MINGUZZI, Andrea             ITA    Men                   74 - 84kg
# FODOR, Zoltan                HUN    Men                   74 - 84kg
# MAMBETOV, Asset              KAZ    Men                   84 - 96kg
# WHEELER, Adam                USA    Men                   84 - 96kg
# KHUSHTOV, Aslanbek           RUS    Men                   84 - 96kg
# ENGLICH, Mirko               GER    Men                   84 - 96kg
# MIZGAITIS, Mindaugas         LTU    Men                  96 - 120kg
# PATRIKEEV, Yuri              ARM    Men                  96 - 120kg
# LOPEZ, Mijain                CUB    Men                  96 - 120kg
# BAROEV, Khasan               RUS    Men                  96 - 120kg
#
#                             Event_gender   Medal
# Athlete
# HAJOS, Alfred                          M    Gold
# HERSCHMANN, Otto                       M  Silver
# DRIVAS, Dimitrios                      M  Bronze
# MALOKINIS, Ioannis                     M    Gold
# CHASAPIS, Spiridon                     M  Silver
# CHOROPHAS, Efstathios                  M  Bronze
# HAJOS, Alfred                          M    Gold
# ANDREOU, Joannis                       M  Silver
# CHOROPHAS, Efstathios                  M  Bronze
# NEUMANN, Paul                          M    Gold
# PEPANOS, Antonios                      M  Silver
# LANE, Francis                          M  Bronze
# SZOKOLYI, Alajos                       M  Bronze
# BURKE, Thomas                          M    Gold
# HOFMANN, Fritz                         M  Silver
# CURTIS, Thomas                         M    Gold
# GOULDING, Grantley                     M  Silver
# LERMUSIAUX, Albin                      M  Bronze
# FLACK, Edwin                           M    Gold
# BLAKE, Arthur                          M  Silver
# GMELIN, Charles                        M  Bronze
# BURKE, Thomas                          M    Gold
# JAMISON, Herbert                       M  Silver
# GOLEMIS, Dimitrios                     M  Bronze
# FLACK, Edwin                           M    Gold
# DANI, Nandor                           M  Silver
# VERSIS, Sotirios                       M  Bronze
# GARRETT, Robert                        M    Gold
# PARASKEVOPOULOS, Panagiotis            M  Silver
# CLARK, Ellery                          M    Gold
# ...                                  ...     ...
# MUTALIMOV, Marid                       M  Bronze
# TAYMAZOV, Artur                        M    Gold
# AKHMEDOV, Bakhtiyar                    M  Silver
# AMOYAN, Roman                          M  Bronze
# PARK, Eun-Chul                         M  Bronze
# MANKIEV, Nazyr                         M    Gold
# BAYRAMOV, Rovshan                      M  Silver
# TENGIZBAYEV, Nurbakyt                  M  Bronze
# TIUMENBAEV, Ruslan                     M  Bronze
# ALBIEV, Islam-Beka                     M    Gold
# RAHIMOV, Vitaliy                       M  Silver
# SIAMIONAU, Mikhail                     M  Bronze
# VARDANYAN, Armen                       M  Bronze
# GUENOT, Steeve                         M    Gold
# BEGALIEV, Kanatbek                     M  Silver
# GUENOT, Christophe                     M  Bronze
# YANAKIEV, Yavor                        M  Bronze
# KVIRKELIA, Manuchar                    M    Gold
# CHANG, Yongxiang                       M  Silver
# AVLUCA, Nazmi                          M  Bronze
# MINGUZZI, Andrea                       M    Gold
# FODOR, Zoltan                          M  Silver
# MAMBETOV, Asset                        M  Bronze
# WHEELER, Adam                          M  Bronze
# KHUSHTOV, Aslanbek                     M    Gold
# ENGLICH, Mirko                         M  Silver
# MIZGAITIS, Mindaugas                   M  Bronze
# PATRIKEEV, Yuri                        M  Bronze
# LOPEZ, Mijain                          M    Gold
# BAROEV, Khasan                         M  Silver
#
# [29216 rows x 9 columns]

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df.set_index('Athlete',inplace=True)
df.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
df.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
#OR if we make a copy of the dataframe then set_index works without inplace=True .
df.reset_index(inplace=True)
ath=df.set_index('Athlete')
ath.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
df.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
ath.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath.sort_index(inplace=True)
ath.head()
# Out:
#                              City  Edition       Sport   Discipline  NOC  \
# Athlete
# AABYE, Edgar                Paris     1900  Tug of War   Tug of War  ZZX
# AALTONEN, Arvo Ossian     Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Arvo Ossian     Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Paavo Johannes   London     1948  Gymnastics  Artistic G.  FIN
# AALTONEN, Paavo Johannes   London     1948  Gymnastics  Artistic G.  FIN
#
#                          Gender              Event Event_gender   Medal
# Athlete
# AABYE, Edgar                Men         tug of war            M    Gold
# AALTONEN, Arvo Ossian       Men  200m breaststroke            M  Bronze
# AALTONEN, Arvo Ossian       Men  400m breaststroke            M  Bronze
# AALTONEN, Paavo Johannes    Men       pommel horse            M    Gold
# AALTONEN, Paavo Johannes    Men   team competition            M    Gold

# %%
ath.sort_index(inplace=True,ascending=False)
ath.head()
# Out:
#                        City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# ÖSTRAND, Per-Olof  Helsinki     1952  Aquatics   Swimming  SWE    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
#
#                                            Event Event_gender   Medal
# Athlete
# ÖSTRAND, Per-Olof                 400m freestyle            M  Bronze
# ÖSTMO, Ole         army rifle, 300m, 3 positions            M  Bronze
# ÖSTMO, Ole                      free rifle, team            M  Silver
# ÖSTMO, Ole            army rifle, 300m, standing            M  Silver
# ÖSTMO, Ole               army rifle, 300m, prone            M  Bronze

# %% [markdown]
# <h3>LOC </h3>"loc[]" is a label-based indexer, that means you are selecting by the labels. And notice that "loc[]" uses square brackets and not regular brackets. "loc[]" will raise the KeyError when items are not found.

# %%
ath.reset_index(inplace=True)
ath.head()
# Out:
#              Athlete      City  Edition     Sport Discipline  NOC Gender  \
# 0  ÖSTRAND, Per-Olof  Helsinki     1952  Aquatics   Swimming  SWE    Men
# 1         ÖSTMO, Ole     Paris     1900  Shooting   Shooting  NOR    Men
# 2         ÖSTMO, Ole     Paris     1900  Shooting   Shooting  NOR    Men
# 3         ÖSTMO, Ole     Paris     1900  Shooting   Shooting  NOR    Men
# 4         ÖSTMO, Ole     Paris     1900  Shooting   Shooting  NOR    Men
#
#                            Event Event_gender   Medal
# 0                 400m freestyle            M  Bronze
# 1  army rifle, 300m, 3 positions            M  Bronze
# 2               free rifle, team            M  Silver
# 3     army rifle, 300m, standing            M  Silver
# 4        army rifle, 300m, prone            M  Bronze

# %%
ath.loc['AALTONEN, Arvo Ossian']#We will get key error becos we have to first set the index to Athelete
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/dhanu/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# /Users/dhanu/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [AALTONEN, Arvo Ossian] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-061b0034f475> in <module>()
# ----> 1 ath.loc['AALTONEN, Arvo Ossian']#We will get key error becos we have to first set the index to Athelete
#
# /Users/dhanu/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /Users/dhanu/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1549
#    1550         # fall thru to straight lookup
# -> 1551         self._has_valid_type(key, axis)
#    1552         return self._get_label(key, axis=axis)
#    1553
#
# /Users/dhanu/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1440                 raise
#    1441             except:
# -> 1442                 error()
#    1443
#    1444         return True
#
# /Users/dhanu/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1427                                     "key")
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#    1431             try:
#
# KeyError: 'the label [AALTONEN, Arvo Ossian] is not in the [index]'

# %%
ath.set_index('Athlete',inplace=True)
ath.head()
# Out:
#                        City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# ÖSTRAND, Per-Olof  Helsinki     1952  Aquatics   Swimming  SWE    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
#
#                                            Event Event_gender   Medal
# Athlete
# ÖSTRAND, Per-Olof                 400m freestyle            M  Bronze
# ÖSTMO, Ole         army rifle, 300m, 3 positions            M  Bronze
# ÖSTMO, Ole                      free rifle, team            M  Silver
# ÖSTMO, Ole            army rifle, 300m, standing            M  Silver
# ÖSTMO, Ole               army rifle, 300m, prone            M  Bronze

# %%
ath.loc['AALTONEN, Arvo Ossian']
# Out:
#                           City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# AALTONEN, Arvo Ossian  Antwerp     1920  Aquatics   Swimming  FIN    Men
# AALTONEN, Arvo Ossian  Antwerp     1920  Aquatics   Swimming  FIN    Men
#
#                                    Event Event_gender   Medal
# Athlete
# AALTONEN, Arvo Ossian  400m breaststroke            M  Bronze
# AALTONEN, Arvo Ossian  200m breaststroke            M  Bronze

# %%
#Usual method
ath.reset_index(inplace=True)
ath[ath.Athlete=='AALTONEN, Arvo Ossian']
# Out:
#                      Athlete     City  Edition     Sport Discipline  NOC  \
# 29213  AALTONEN, Arvo Ossian  Antwerp     1920  Aquatics   Swimming  FIN
# 29214  AALTONEN, Arvo Ossian  Antwerp     1920  Aquatics   Swimming  FIN
#
#       Gender              Event Event_gender   Medal
# 29213    Men  400m breaststroke            M  Bronze
# 29214    Men  200m breaststroke            M  Bronze

# %%
#we will get the same result with loc
ath.loc[ath.Athlete=='AALTONEN, Arvo Ossian']
# Out:
#                      Athlete     City  Edition     Sport Discipline  NOC  \
# 29213  AALTONEN, Arvo Ossian  Antwerp     1920  Aquatics   Swimming  FIN
# 29214  AALTONEN, Arvo Ossian  Antwerp     1920  Aquatics   Swimming  FIN
#
#       Gender              Event Event_gender   Medal
# 29213    Men  400m breaststroke            M  Bronze
# 29214    Men  200m breaststroke            M  Bronze

# %% [markdown]
# <h3>Iloc</h3> we're doing selection by integer index. Iloc is primarily integer position based. One of the advantages of Iloc is that it allows for the traditional Pythonic slicing.

# %%
df.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df.iloc[1700]
# Out:
# Athlete         RABOT, Pierre
# City                   London
# Edition                  1908
# Sport                 Sailing
# Discipline            Sailing
# NOC                       FRA
# Gender                    Men
# Event                      6m
# Event_gender                X
# Medal                  Bronze
# Name: 1700, dtype: object

# %%
df.iloc[[3,6,30]]
# Out:
#                Athlete    City  Edition      Sport Discipline  NOC Gender  \
# 3   MALOKINIS, Ioannis  Athens     1896   Aquatics   Swimming  GRE    Men
# 6        HAJOS, Alfred  Athens     1896   Aquatics   Swimming  HUN    Men
# 30     CONNOLLY, James  Athens     1896  Athletics  Athletics  USA    Men
#
#                          Event Event_gender   Medal
# 3   100m freestyle for sailors            M    Gold
# 6              1200m freestyle            M    Gold
# 30                   high jump            M  Silver

# %%
df.iloc[1:5]
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df.Medal.value_counts()
# Out:
# Gold      9850
# Bronze    9689
# Silver    9677
# Name: Medal, dtype: int64

# %%
#
df.reset_index(inplace=True)
df.head()
# Out:
#    index             Athlete    City  Edition     Sport Discipline  NOC  \
# 0      0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN
# 1      1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT
# 2      2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE
# 3      3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE
# 4      4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE
#
#   Gender                       Event Event_gender   Medal
# 0    Men              100m freestyle            M    Gold
# 1    Men              100m freestyle            M  Silver
# 2    Men  100m freestyle for sailors            M  Bronze
# 3    Men  100m freestyle for sailors            M    Gold
# 4    Men  100m freestyle for sailors            M  Silver

# %%
df.Edition.value_counts().sort_index().plot()

# %%
df2008=df[df.Edition==2008]
df2008.head()
# Out:
#        index           Athlete     City  Edition     Sport Discipline  NOC  \
# 27174  27174    GALPERIN, Gleb  Beijing     2008  Aquatics     Diving  RUS
# 27175  27175  MITCHAM, Matthew  Beijing     2008  Aquatics     Diving  AUS
# 27176  27176       ZHOU, Luxin  Beijing     2008  Aquatics     Diving  CHN
# 27177  27177         WANG, Xin  Beijing     2008  Aquatics     Diving  CHN
# 27178  27178      CHEN, Ruolin  Beijing     2008  Aquatics     Diving  CHN
#
#       Gender         Event Event_gender   Medal
# 27174    Men  10m platform            M  Bronze
# 27175    Men  10m platform            M    Gold
# 27176    Men  10m platform            M  Silver
# 27177  Women  10m platform            W  Bronze
# 27178  Women  10m platform            W    Gold

# %%
noc=pd.read_csv('ExerciseFiles/Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv')
noc.head()
# Out:
#            Country Int Olympic Committee code ISO code        Country.1
# 0      Afghanistan                        AFG       AF      Afghanistan
# 1          Albania                        ALB       AL          Albania
# 2          Algeria                        ALG       DZ          Algeria
# 3  American Samoa*                        ASA       AS  American Samoa*
# 4          Andorra                        AND       AD          Andorra

# %%
noc.set_index('Int Olympic Committee code',inplace=True)
noc.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
noc2008=df2008.NOC.value_counts()
noc2008
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
# KOR     78
# GBR     77
# FRA     76
# BRA     75
# ESP     71
# NED     62
# ARG     51
# JPN     51
# CUB     47
# ITA     42
# CAN     34
# UKR     31
# BLR     30
# HUN     27
# NGR     24
# NOR     22
# ROU     22
# POL     20
# DEN     18
# JAM     17
# SRB     15
# ISL     14
# KEN     14
# NZL     14
# KAZ     13
#       ...
# SIN      3
# LAT      3
# IRL      3
# EST      3
# AUT      3
# IND      3
# DOM      2
# MAR      2
# COL      2
# TJK      2
# POR      2
# KGZ      2
# ALG      2
# IRI      2
# MRI      1
# ECU      1
# ISR      1
# EGY      1
# TUN      1
# MDA      1
# AFG      1
# VIE      1
# PAN      1
# CMR      1
# VEN      1
# RSA      1
# CHI      1
# TOG      1
# SUD      1
# MAS      1
# Name: NOC, Length: 86, dtype: int64

# %%
noc["y2002"]=noc2008

# %%
noc.head()
# Out:
#                                     Country ISO code        Country.1  y2002
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan    1.0
# ALB                                 Albania       AL          Albania    NaN
# ALG                                 Algeria       DZ          Algeria    2.0
# ASA                         American Samoa*       AS  American Samoa*    NaN
# AND                                 Andorra       AD          Andorra    NaN

# %%
noc[noc.y2002.isnull()]
# Out:
#                                                      Country ISO code  \
# Int Olympic Committee code
# ALB                                                  Albania       AL
# ASA                                          American Samoa*       AS
# AND                                                  Andorra       AD
# ANG                                                   Angola       AO
# ANT                                      Antigua and Barbuda       AG
# ARU                                                   Aruba*       AW
# BRN                                                  Bahrain       BH
# BAN                                               Bangladesh       BD
# BAR                                                 Barbados       BB
# BIZ                                                   Belize       BZ
# BER                                                 Bermuda*       BM
# BEN                                                    Benin       BJ
# BHU                                                   Bhutan       BT
# BOL                                                  Bolivia       BO
# BIH                                   Bosnia and Herzegovina       BA
# BOT                                                 Botswana       BW
# IVB                                   British Virgin Islands       VG
# BRU                                                   Brunei       BN
# BUR                                             Burkina Faso       BF
# BDI                                                  Burundi       BI
# CAM                                                 Cambodia       KH
# CPV                                               Cape Verde       CV
# CAY                                          Cayman Islands*       KY
# CAF                                 Central African Republic       CF
# CHA                                                     Chad       TD
# COM                                                  Comoros       KM
# CGO                                                    Congo       CG
# COD                                           Congo, Dem Rep       CD
# COK                                             Cook Islands       CK
# CRC                                               Costa Rica       CR
# ...                                                      ...      ...
# QAT                                                    Qatar       QA
# ROM                                                  Romania       RO
# RWA                                                   Rwanda       RW
# SKN                                    Saint Kitts and Nevis       KN
# LCA                                              Saint Lucia       LC
# VIN                         Saint Vincent and the Grenadines       VC
# SAM                                                    Samoa       WS
# SMR                                               San Marino       SM
# STP                                    Sao Tome and Principe       ST
# KSA                                             Saudi Arabia       SA
# SEN                                                  Senegal       SN
# SCG                                                   Serbia       RS
# SEY                                               Seychelles       SC
# SLE                                             Sierra Leone       SL
# SOL                                          Solomon Islands       SB
# SOM                                                  Somalia       SO
# SRI                                                Sri Lanka       LK
# SUR                                                 Suriname       SR
# SWZ                                                Swaziland       SZ
# SYR                                                    Syria       SY
# TAN                                                 Tanzania       TZ
# TGA                                                    Tonga       TO
# TKM                                             Turkmenistan       TM
# UGA                                                   Uganda       UG
# UAE                                     United Arab Emirates       AE
# URU                                                  Uruguay       UY
# VAN                                                  Vanuatu       VU
# ISV                                          Virgin Islands*       VI
# YEM                                                    Yemen       YE
# ZAM                                                   Zambia       ZM
#
#                                                    Country.1  y2002
# Int Olympic Committee code
# ALB                                                  Albania    NaN
# ASA                                          American Samoa*    NaN
# AND                                                  Andorra    NaN
# ANG                                                   Angola    NaN
# ANT                                      Antigua and Barbuda    NaN
# ARU                                                   Aruba*    NaN
# BRN                                                  Bahrain    NaN
# BAN                                               Bangladesh    NaN
# BAR                                                 Barbados    NaN
# BIZ                                                   Belize    NaN
# BER                                                 Bermuda*    NaN
# BEN                                                    Benin    NaN
# BHU                                                   Bhutan    NaN
# BOL                                                  Bolivia    NaN
# BIH                                   Bosnia and Herzegovina    NaN
# BOT                                                 Botswana    NaN
# IVB                                   British Virgin Islands    NaN
# BRU                                                   Brunei    NaN
# BUR                                             Burkina Faso    NaN
# BDI                                                  Burundi    NaN
# CAM                                                 Cambodia    NaN
# CPV                                               Cape Verde    NaN
# CAY                                          Cayman Islands*    NaN
# CAF                                 Central African Republic    NaN
# CHA                                                     Chad    NaN
# COM                                                  Comoros    NaN
# CGO                                                    Congo    NaN
# COD                                           Congo, Dem Rep    NaN
# COK                                             Cook Islands    NaN
# CRC                                               Costa Rica    NaN
# ...                                                      ...    ...
# QAT                                                    Qatar    NaN
# ROM                                                  Romania    NaN
# RWA                                                   Rwanda    NaN
# SKN                                    Saint Kitts and Nevis    NaN
# LCA                                              Saint Lucia    NaN
# VIN                         Saint Vincent and the Grenadines    NaN
# SAM                                                    Samoa    NaN
# SMR                                               San Marino    NaN
# STP                                    Sao Tome and Principe    NaN
# KSA                                             Saudi Arabia    NaN
# SEN                                                  Senegal    NaN
# SCG                                                   Serbia    NaN
# SEY                                               Seychelles    NaN
# SLE                                             Sierra Leone    NaN
# SOL                                          Solomon Islands    NaN
# SOM                                                  Somalia    NaN
# SRI                                                Sri Lanka    NaN
# SUR                                                 Suriname    NaN
# SWZ                                                Swaziland    NaN
# SYR                                                    Syria    NaN
# TAN                                                 Tanzania    NaN
# TGA                                                    Tonga    NaN
# TKM                                             Turkmenistan    NaN
# UGA                                                   Uganda    NaN
# UAE                                     United Arab Emirates    NaN
# URU                                                  Uruguay    NaN
# VAN                                                  Vanuatu    NaN
# ISV                                          Virgin Islands*    NaN
# YEM                                                    Yemen    NaN
# ZAM                                                   Zambia    NaN
#
# [117 rows x 4 columns]

# %% [markdown]
# <h3>Groupby</h3>Groupby is one of the most important functionalities available in Pandas. Groupby does three things. It splits a DataFrame into groups based on some criteria, it applies a function to each group independently and it combines the results into a DataFrame. Now, many people when they first learn how to use the Groupby function, don't know what to do with the Groupby object. Creating the Groupby object only verifies that you've passed a valid mapping. The Groupby object isn't a DataFrame but rather a group of DataFrames in a dict-like structure.
#
# On the next slide, we have a useful visualization that helps us show what the Groupby function does. So, Groupby splits the DataFrame into groups. Each of these groups remember is a DataFrame, it applies a function for each group and then finally it combines the results into a DataFrame.

# %%
df.head()
# Out:
#    index             Athlete    City  Edition     Sport Discipline  NOC  \
# 0      0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN
# 1      1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT
# 2      2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE
# 3      3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE
# 4      4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE
#
#   Gender                       Event Event_gender   Medal
# 0    Men              100m freestyle            M    Gold
# 1    Men              100m freestyle            M  Silver
# 2    Men  100m freestyle for sailors            M  Bronze
# 3    Men  100m freestyle for sailors            M    Gold
# 4    Men  100m freestyle for sailors            M  Silver

# %%
edi=df.groupby('Edition')

# %%
edi.head()
# Out:
#        index                      Athlete       City  Edition     Sport  \
# 0          0                HAJOS, Alfred     Athens     1896  Aquatics
# 1          1             HERSCHMANN, Otto     Athens     1896  Aquatics
# 2          2            DRIVAS, Dimitrios     Athens     1896  Aquatics
# 3          3           MALOKINIS, Ioannis     Athens     1896  Aquatics
# 4          4           CHASAPIS, Spiridon     Athens     1896  Aquatics
# 151      151               HALMAY, Zoltan      Paris     1900  Aquatics
# 152      152          JARVIS, John Arthur      Paris     1900  Aquatics
# 153      153                  WAHLE, Otto      Paris     1900  Aquatics
# 154      154              DROST, Johannes      Paris     1900  Aquatics
# 155      155            HOPPENBERG, Ernst      Paris     1900  Aquatics
# 663      663       BRAUNSCHWEIGER, Alfred   St Louis     1904  Aquatics
# 664      664                 KEHOE, Frank   St Louis     1904  Aquatics
# 665      665              SHELDON, George   St Louis     1904  Aquatics
# 666      666              HOFFMANN, Georg   St Louis     1904  Aquatics
# 667      667            GOODWIN, Leo Budd   St Louis     1904  Aquatics
# 1133    1133             SPANGBERG, Arvid     London     1908  Aquatics
# 1134    1134           JOHANSSON, Hjalmar     London     1908  Aquatics
# 1135    1135              MALMSTRÖM, Karl     London     1908  Aquatics
# 1136    1136      GAIDZIK, George William     London     1908  Aquatics
# 1137    1137                WALZ, Gottlob     London     1908  Aquatics
# 1937    1937             BLOMGREN, Gustaf  Stockholm     1912  Aquatics
# 1938    1938                 ADLERZ, Erik  Stockholm     1912  Aquatics
# 1939    1939               ZÜRNER, Albert  Stockholm     1912  Aquatics
# 1940    1940         WHITE, Isabella Mary  Stockholm     1912  Aquatics
# 1941    1941             JOHANSSON, Greta  Stockholm     1912  Aquatics
# 2822    2822               PRIESTE, Harry    Antwerp     1920  Aquatics
# 2823    2823           PINKSTON, Clarence    Antwerp     1920  Aquatics
# 2824    2824                 ADLERZ, Erik    Antwerp     1920  Aquatics
# 2825    2825                OLLIVIER, Eva    Antwerp     1920  Aquatics
# 2826    2826     FRYLAND CLAUSEN, Stefani    Antwerp     1920  Aquatics
# ...      ...                          ...        ...      ...       ...
# 18051  18051           MENA CAMPOS, Jesus      Seoul     1988  Aquatics
# 18052  18052            LOUGANIS, Gregory      Seoul     1988  Aquatics
# 18053  18053                    XIONG, Ni      Seoul     1988  Aquatics
# 18054  18054  WYLAND-WILLIAMS, Wendy Lian      Seoul     1988  Aquatics
# 18055  18055                  XU, Yan-Mei      Seoul     1988  Aquatics
# 19597  19597                    XIONG, Ni  Barcelona     1992  Aquatics
# 19598  19598                  SUN, Shuwei  Barcelona     1992  Aquatics
# 19599  19599              DONIE, Scott R.  Barcelona     1992  Aquatics
# 19600  19600            CLARK, Mary Ellen  Barcelona     1992  Aquatics
# 19601  19601                  FU, Mingxia  Barcelona     1992  Aquatics
# 21302  21302               XIAO, Hailiang    Atlanta     1996  Aquatics
# 21303  21303               SAUTIN, Dmitry    Atlanta     1996  Aquatics
# 21304  21304                  HEMPEL, Jan    Atlanta     1996  Aquatics
# 21305  21305            CLARK, Mary Ellen    Atlanta     1996  Aquatics
# 21306  21306                  FU, Mingxia    Atlanta     1996  Aquatics
# 23161  23161               SAUTIN, Dmitry     Sydney     2000  Aquatics
# 23162  23162                  TIAN, Liang     Sydney     2000  Aquatics
# 23163  23163                      HU, Jia     Sydney     2000  Aquatics
# 23164  23164     MONTMINY, Anne Katherine     Sydney     2000  Aquatics
# 23165  23165             WILKINSON, Laura     Sydney     2000  Aquatics
# 25176  25176                  TIAN, Liang     Athens     2004  Aquatics
# 25177  25177                      HU, Jia     Athens     2004  Aquatics
# 25178  25178                 HELM, Mathew     Athens     2004  Aquatics
# 25179  25179                TOURKY, Loudy     Athens     2004  Aquatics
# 25180  25180           NEWBERY, Chantelle     Athens     2004  Aquatics
# 27174  27174               GALPERIN, Gleb    Beijing     2008  Aquatics
# 27175  27175             MITCHAM, Matthew    Beijing     2008  Aquatics
# 27176  27176                  ZHOU, Luxin    Beijing     2008  Aquatics
# 27177  27177                    WANG, Xin    Beijing     2008  Aquatics
# 27178  27178                 CHEN, Ruolin    Beijing     2008  Aquatics
#
#       Discipline  NOC Gender                       Event Event_gender   Medal
# 0       Swimming  HUN    Men              100m freestyle            M    Gold
# 1       Swimming  AUT    Men              100m freestyle            M  Silver
# 2       Swimming  GRE    Men  100m freestyle for sailors            M  Bronze
# 3       Swimming  GRE    Men  100m freestyle for sailors            M    Gold
# 4       Swimming  GRE    Men  100m freestyle for sailors            M  Silver
# 151     Swimming  HUN    Men             1500m freestyle            M  Bronze
# 152     Swimming  GBR    Men             1500m freestyle            M    Gold
# 153     Swimming  AUT    Men             1500m freestyle            M  Silver
# 154     Swimming  NED    Men             200m backstroke            M  Bronze
# 155     Swimming  GER    Men             200m backstroke            M    Gold
# 663       Diving  GER    Men                10m platform            M  Bronze
# 664       Diving  USA    Men                10m platform            M  Bronze
# 665       Diving  USA    Men                10m platform            M    Gold
# 666       Diving  GER    Men                10m platform            M  Silver
# 667       Diving  USA    Men         plunge for distance            M  Bronze
# 1133      Diving  SWE    Men                10m platform            M  Bronze
# 1134      Diving  SWE    Men                10m platform            M    Gold
# 1135      Diving  SWE    Men                10m platform            M  Silver
# 1136      Diving  USA    Men              3m springboard            M  Bronze
# 1137      Diving  GER    Men              3m springboard            M  Bronze
# 1937      Diving  SWE    Men                10m platform            M  Bronze
# 1938      Diving  SWE    Men                10m platform            M    Gold
# 1939      Diving  GER    Men                10m platform            M  Silver
# 1940      Diving  GBR  Women                10m platform            W  Bronze
# 1941      Diving  SWE  Women                10m platform            W    Gold
# 2822      Diving  USA    Men                10m platform            M  Bronze
# 2823      Diving  USA    Men                10m platform            M    Gold
# 2824      Diving  SWE    Men                10m platform            M  Silver
# 2825      Diving  SWE  Women                10m platform            W  Bronze
# 2826      Diving  DEN  Women                10m platform            W    Gold
# ...          ...  ...    ...                         ...          ...     ...
# 18051     Diving  MEX    Men                10m platform            M  Bronze
# 18052     Diving  USA    Men                10m platform            M    Gold
# 18053     Diving  CHN    Men                10m platform            M  Silver
# 18054     Diving  USA  Women                10m platform            W  Bronze
# 18055     Diving  CHN  Women                10m platform            W    Gold
# 19597     Diving  CHN    Men                10m platform            M  Bronze
# 19598     Diving  CHN    Men                10m platform            M    Gold
# 19599     Diving  USA    Men                10m platform            M  Silver
# 19600     Diving  USA  Women                10m platform            W  Bronze
# 19601     Diving  CHN  Women                10m platform            W    Gold
# 21302     Diving  CHN    Men                10m platform            M  Bronze
# 21303     Diving  RUS    Men                10m platform            M    Gold
# 21304     Diving  GER    Men                10m platform            M  Silver
# 21305     Diving  USA  Women                10m platform            W  Bronze
# 21306     Diving  CHN  Women                10m platform            W    Gold
# 23161     Diving  RUS    Men                10m platform            M  Bronze
# 23162     Diving  CHN    Men                10m platform            M    Gold
# 23163     Diving  CHN    Men                10m platform            M  Silver
# 23164     Diving  CAN  Women                10m platform            W  Bronze
# 23165     Diving  USA  Women                10m platform            W    Gold
# 25176     Diving  CHN    Men                10m platform            M  Bronze
# 25177     Diving  CHN    Men                10m platform            M    Gold
# 25178     Diving  AUS    Men                10m platform            M  Silver
# 25179     Diving  AUS  Women                10m platform            W  Bronze
# 25180     Diving  AUS  Women                10m platform            W    Gold
# 27174     Diving  RUS    Men                10m platform            M  Bronze
# 27175     Diving  AUS    Men                10m platform            M    Gold
# 27176     Diving  CHN    Men                10m platform            M  Silver
# 27177     Diving  CHN  Women                10m platform            W  Bronze
# 27178     Diving  CHN  Women                10m platform            W    Gold
#
# [130 rows x 11 columns]

# %%
for key,group in df.groupby('Edition'):#Key will be olymbic edition/year,group will be all of the rows corresponding to that key
   print(key)
# Out:
# 1896
# 1900
# 1904
# 1908
# 1912
# 1920
# 1924
# 1928
# 1932
# 1936
# 1948
# 1952
# 1956
# 1960
# 1964
# 1968
# 1972
# 1976
# 1980
# 1984
# 1988
# 1992
# 1996
# 2000
# 2004
# 2008

# %%
type(key)
# Out:
# numpy.int64

# %%
type(group)
# Out:
# pandas.core.frame.DataFrame

# %%
df.groupby('Edition').size()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
df.groupby(['Edition','NOC','Medal']).agg(['min','max','count'])
# Out:
#                     index                                         Athlete  \
#                       min    max count                                min
# Edition NOC Medal
# 1896    AUS Gold       18     24     2                       FLACK, Edwin
#         AUT Bronze     53     58     2                      SCHMAL, Adolf
#             Gold        9     56     2                      NEUMANN, Paul
#             Silver      1      1     1                   HERSCHMANN, Otto
#         DEN Bronze     69    129     3                      JENSEN, Viggo
#             Gold      146    146     1                      JENSEN, Viggo
#             Silver    125    144     2                      JENSEN, Viggo
#         FRA Bronze     17     61     2                      FLAMENG, Léon
#             Gold       51     65     5                      FLAMENG, Léon
#             Silver     47     68     4                      CALLOT, Henri
#         GBR Bronze     20     48     2                     BATTEL, Edward
#             Gold      140    143     2                       BOLAND, John
#             Silver     16    147     3                ELLIOTT, Launceston
#         GER Bronze     81    114     2                     HOFMANN, Fritz
#             Gold       72    149    26                     BÖCKER, Konrad
#             Silver     14     80     5                     FLATOW, Alfred
#         GRE Bronze      2    148    22              CHOROPHAS, Efstathios
#             Gold        3    130    10           ANDRIAKOPOULOS, Nicolaos
#             Silver      4    150    20                   ANDREOU, Joannis
#         HUN Bronze     12    139     3                     KELLNER, Gyula
#             Gold        0      6     2                      HAJOS, Alfred
#             Silver     25     25     1                       DANI, Nandor
#         SUI Gold       76     76     1                      ZUTTER, Louis
#             Silver     75    116     2                      ZUTTER, Louis
#         USA Bronze     11     32     2                    CONNOLLY, James
#             Gold       13    124    11                      BURKE, Thomas
#             Silver     19    119     7                      BLAKE, Arthur
#         ZZX Bronze    132    133     2                       FLACK, Edwin
#             Gold      134    135     2                       BOLAND, John
#             Silver    136    137     2               KASDAGLIS, Dionysios
# ...                   ...    ...   ...                                ...
# 2008    SUI Gold    28030  28995     3                 CANCELLARA, Fabian
#         SVK Bronze  29185  29185     1                    MUSULBES, David
#             Gold    28004  28016     4                HOCHSCHORNER, Pavol
#             Silver  27987  28890     5                 RISZDORFER, Michal
#         SWE Bronze  28825  28826     2                    EKSTROM, Anders
#             Silver  28028  28997     5                     ASPELIN, Simon
#         THA Gold    27896  29116     2  JAROENRATTANATARAKOON, Prapawadee
#             Silver  27917  28963     2                 BOONJUMNONG, Manus
#         TJK Bronze  28622  28622     1                      BOQIEV, Rasul
#             Silver  29180  29180     1                 ABDUSALOMOV, Yusup
#         TOG Bronze  28012  28012     1                 BOUKPETI, Benjamin
#         TPE Bronze  28964  29124     4                     CHEN, Wei-Ling
#         TRI Silver  27553  27610     5                    BLEDMAN, Keston
#         TUN Gold    27237  27237     1                  MELLOULI, Oussama
#         TUR Bronze  27907  29205     3                      AVLUCA, Nazmi
#             Gold    29167  29167     1                     SAHIN, Ramazan
#             Silver  27550  29114     4                 ABEYLEGESSE, Elvan
#         UKR Bronze  27198  29198    16                    ANTONOVA, Olena
#             Gold    27522  28874    10                    AYVAZYAN, Artur
#             Silver  27568  29168     5                  FEDORYSHYN, Vasyl
#         USA Bronze  27214  29209    81                       ALLEN, Wyatt
#             Gold    27212  29151   125                     ADRIAN, Nathan
#             Silver  27213  29099   109                     ABBOTT, Monica
#         UZB Bronze  28322  28591     3                       FOKIN, Anton
#             Gold    29187  29187     1                    TAYMAZOV, Artur
#             Silver  28597  29176     2                  TANGRIEV, Abdullo
#         VEN Bronze  28960  28960     1            CONTRERAS RIVERO, Dalia
#         VIE Silver  29102  29102     1                    HOANG, Anh Tuan
#         ZIM Gold    27243  27243     1                   COVENTRY, Kirsty
#             Silver  27216  27280     3                   COVENTRY, Kirsty
#
#                                                        City                 \
#                                          max count      min      max count
# Edition NOC Medal
# 1896    AUS Gold                FLACK, Edwin     2   Athens   Athens     2
#         AUT Bronze             SCHMAL, Adolf     2   Athens   Athens     2
#             Gold               SCHMAL, Adolf     2   Athens   Athens     2
#             Silver          HERSCHMANN, Otto     1   Athens   Athens     1
#         DEN Bronze           NIELSEN, Holger     3   Athens   Athens     3
#             Gold               JENSEN, Viggo     1   Athens   Athens     1
#             Silver           NIELSEN, Holger     2   Athens   Athens     2
#         FRA Bronze         LERMUSIAUX, Albin     2   Athens   Athens     2
#             Gold                MASSON, Paul     5   Athens   Athens     5
#             Silver        TUFFERI, Alexandre     4   Athens   Athens     4
#         GBR Bronze           GMELIN, Charles     2   Athens   Athens     2
#             Gold         ELLIOTT, Launceston     2   Athens   Athens     2
#             Silver            KEEPING, Frank     3   Athens   Athens     3
#         GER Bronze      WEINGÄRTNER, Hermann     2   Athens   Athens     2
#             Gold        WEINGÄRTNER, Hermann    26   Athens   Athens    26
#             Silver      WEINGÄRTNER, Hermann     5   Athens   Athens     5
#         GRE Bronze          VERSIS, Sotirios    22   Athens   Athens    22
#             Gold            PYRGOS, Leonidas    10   Athens   Athens    10
#             Silver        XENAKIS, Thomasios    20   Athens   Athens    20
#         HUN Bronze      TAPAVICZA, Momcsillo     3   Athens   Athens     3
#             Gold               HAJOS, Alfred     2   Athens   Athens     2
#             Silver              DANI, Nandor     1   Athens   Athens     1
#         SUI Gold               ZUTTER, Louis     1   Athens   Athens     1
#             Silver             ZUTTER, Louis     2   Athens   Athens     2
#         USA Bronze             LANE, Francis     2   Athens   Athens     2
#             Gold               PAINE, Sumner    11   Athens   Athens    11
#             Silver             TYLER, Albert     7   Athens   Athens     7
#         ZZX Bronze  ROBERTSON, George Stuart     2   Athens   Athens     2
#             Gold            TRAUN, Friedrich     2   Athens   Athens     2
#             Silver  PETROKOKKINOS, Demetrios     2   Athens   Athens     2
# ...                                      ...   ...      ...      ...   ...
# 2008    SUI Gold         WAWRINKA, Stanislas     3  Beijing  Beijing     3
#         SVK Bronze           MUSULBES, David     1  Beijing  Beijing     1
#             Gold            MARTIKAN, Michal     4  Beijing  Beijing     4
#             Silver               VLCEK, Erik     5  Beijing  Beijing     5
#         SWE Bronze             LOOF, Fredrik     2  Beijing  Beijing     2
#             Silver           LARSSON, Gustav     5  Beijing  Beijing     5
#         THA Gold           JONGJOHOR, Somjit     2  Beijing  Beijing     2
#             Silver         PUEDPONG, Buttree     2  Beijing  Beijing     2
#         TJK Bronze             BOQIEV, Rasul     1  Beijing  Beijing     1
#             Silver        ABDUSALOMOV, Yusup     1  Beijing  Beijing     1
#         TOG Bronze        BOUKPETI, Benjamin     1  Beijing  Beijing     1
#         TPE Bronze              SUNG, Yu-Chi     4  Beijing  Beijing     4
#         TRI Silver         THOMPSON, Richard     5  Beijing  Beijing     5
#         TUN Gold           MELLOULI, Oussama     1  Beijing  Beijing     1
#         TUR Bronze           TAZEGUL, Servet     3  Beijing  Beijing     3
#             Gold              SAHIN, Ramazan     1  Beijing  Beijing     1
#             Silver          TANRIKULU, Azize     4  Beijing  Beijing     4
#         UKR Bronze          YURCHENKO, Denys    16  Beijing  Beijing    16
#             Gold               ZHOVNIR, Olha    10  Beijing  Beijing    10
#             Silver         SUKHORUKOV, Yuriy     5  Beijing  Beijing     5
#         USA Bronze           ZAGUNIS, Mariel    81  Beijing  Beijing    81
#             Gold             ZAGUNIS, Mariel   125  Beijing  Beijing   125
#             Silver              WRIGHT, Adam   109  Beijing  Beijing   109
#         UZB Bronze           SOBIROV, Rishod     3  Beijing  Beijing     3
#             Gold             TAYMAZOV, Artur     1  Beijing  Beijing     1
#             Silver            TIGIEV, Soslan     2  Beijing  Beijing     2
#         VEN Bronze   CONTRERAS RIVERO, Dalia     1  Beijing  Beijing     1
#         VIE Silver           HOANG, Anh Tuan     1  Beijing  Beijing     1
#         ZIM Gold            COVENTRY, Kirsty     1  Beijing  Beijing     1
#             Silver          COVENTRY, Kirsty     3  Beijing  Beijing     3
#
#                             Sport  ...  Discipline Gender               \
#                               min  ...       count    min    max count
# Edition NOC Medal                  ...
# 1896    AUS Gold        Athletics  ...           2    Men    Men     2
#         AUT Bronze        Cycling  ...           2    Men    Men     2
#             Gold         Aquatics  ...           2    Men    Men     2
#             Silver       Aquatics  ...           1    Men    Men     1
#         DEN Bronze        Fencing  ...           3    Men    Men     3
#             Gold    Weightlifting  ...           1    Men    Men     1
#             Silver       Shooting  ...           2    Men    Men     2
#         FRA Bronze      Athletics  ...           2    Men    Men     2
#             Gold          Cycling  ...           5    Men    Men     5
#             Silver      Athletics  ...           4    Men    Men     4
#         GBR Bronze      Athletics  ...           2    Men    Men     2
#             Gold           Tennis  ...           2    Men    Men     2
#             Silver      Athletics  ...           3    Men    Men     3
#         GER Bronze     Gymnastics  ...           2    Men    Men     2
#             Gold       Gymnastics  ...          26    Men    Men    26
#             Silver      Athletics  ...           5    Men    Men     5
#         GRE Bronze       Aquatics  ...          22    Men    Men    22
#             Gold         Aquatics  ...          10    Men    Men    10
#             Silver       Aquatics  ...          20    Men    Men    20
#         HUN Bronze      Athletics  ...           3    Men    Men     3
#             Gold         Aquatics  ...           2    Men    Men     2
#             Silver      Athletics  ...           1    Men    Men     1
#         SUI Gold       Gymnastics  ...           1    Men    Men     1
#             Silver     Gymnastics  ...           2    Men    Men     2
#         USA Bronze      Athletics  ...           2    Men    Men     2
#             Gold        Athletics  ...          11    Men    Men    11
#             Silver      Athletics  ...           7    Men    Men     7
#         ZZX Bronze         Tennis  ...           2    Men    Men     2
#             Gold           Tennis  ...           2    Men    Men     2
#             Silver         Tennis  ...           2    Men    Men     2
# ...                           ...  ...         ...    ...    ...   ...
# 2008    SUI Gold          Cycling  ...           3    Men    Men     3
#         SVK Bronze      Wrestling  ...           1    Men    Men     1
#             Gold    Canoe / Kayak  ...           4    Men  Women     4
#             Silver  Canoe / Kayak  ...           5    Men  Women     5
#         SWE Bronze        Sailing  ...           2    Men    Men     2
#             Silver        Cycling  ...           5    Men  Women     5
#         THA Gold           Boxing  ...           2    Men  Women     2
#             Silver         Boxing  ...           2    Men  Women     2
#         TJK Bronze           Judo  ...           1    Men    Men     1
#             Silver      Wrestling  ...           1    Men    Men     1
#         TOG Bronze  Canoe / Kayak  ...           1    Men    Men     1
#         TPE Bronze      Taekwondo  ...           4    Men  Women     4
#         TRI Silver      Athletics  ...           5    Men    Men     5
#         TUN Gold         Aquatics  ...           1    Men    Men     1
#         TUR Bronze         Boxing  ...           3    Men    Men     3
#             Gold        Wrestling  ...           1    Men    Men     1
#             Silver      Athletics  ...           4  Women  Women     4
#         UKR Bronze       Aquatics  ...          16    Men  Women    16
#             Gold          Archery  ...          10    Men  Women    10
#             Silver      Athletics  ...           5    Men  Women     5
#         USA Bronze       Aquatics  ...          81    Men  Women    81
#             Gold         Aquatics  ...         125    Men  Women   125
#             Silver       Aquatics  ...         109    Men  Women   109
#         UZB Bronze     Gymnastics  ...           3    Men  Women     3
#             Gold        Wrestling  ...           1    Men    Men     1
#             Silver           Judo  ...           2    Men    Men     2
#         VEN Bronze      Taekwondo  ...           1  Women  Women     1
#         VIE Silver  Weightlifting  ...           1    Men    Men     1
#         ZIM Gold         Aquatics  ...           1  Women  Women     1
#             Silver       Aquatics  ...           3  Women  Women     3
#
#                                                Event  \
#                                                  min
# Edition NOC Medal
# 1896    AUS Gold                               1500m
#         AUT Bronze                              10km
#             Gold                        12-hour race
#             Silver                    100m freestyle
#         DEN Bronze  25m rapid fire pistol (60 shots)
#             Gold         heavyweight - two hand lift
#             Silver             50m pistol (60 shots)
#         FRA Bronze                             1500m
#             Gold                               100km
#             Silver                              10km
#         GBR Bronze                              400m
#             Gold         heavyweight - one hand lift
#             Silver                      110m hurdles
#         GER Bronze                     rope climbing
#             Gold                      horizontal bar
#             Silver                              100m
#         GRE Bronze        100m freestyle for sailors
#             Gold          100m freestyle for sailors
#             Silver                             100km
#         HUN Bronze                              100m
#             Gold                      100m freestyle
#             Silver                              800m
#         SUI Gold                        pommel horse
#             Silver                     parallel bars
#         USA Bronze                              100m
#             Gold                                100m
#             Silver                             1500m
#         ZZX Bronze                           doubles
#             Gold                             doubles
#             Silver                           doubles
# ...                                              ...
# 2008    SUI Gold                             doubles
#         SVK Bronze                        96 - 120kg
#             Gold                  C-1 (canoe single)
#             Silver            K-4 1000m (kayak four)
#         SWE Bronze                   Star - Keelboat
#             Silver                           doubles
#         THA Gold               48 - 51kg (flyweight)
#             Silver                           - 49 kg
#         TJK Bronze           66 - 73kg (lightweight)
#             Silver                         74 - 84kg
#         TOG Bronze                K-1 (kayak single)
#         TPE Bronze                           - 58 kg
#         TRI Silver                              100m
#         TUN Gold                     1500m freestyle
#         TUR Bronze         54 - 57kg (featherweight)
#             Gold                           60 - 66kg
#             Silver                            10000m
#         UKR Bronze        + 91kg (super heavyweight)
#             Gold    25m rapid fire pistol (60 shots)
#             Silver                            + 75kg
#         USA Bronze                            10000m
#             Gold                              - 55kg
#             Silver                   100m backstroke
#         UZB Bronze                           - 60 kg
#             Gold                          96 - 120kg
#             Silver             + 100kg (heavyweight)
#         VEN Bronze                           - 49 kg
#         VIE Silver      - 56kg, total (bantamweight)
#         ZIM Gold                     200m backstroke
#             Silver                   100m backstroke
#
#                                                              Event_gender      \
#                                                    max count          min max
# Edition NOC Medal
# 1896    AUS Gold                                  800m     2            M   M
#         AUT Bronze                      1km time trial     2            M   M
#             Gold                        400m freestyle     2            M   M
#             Silver                      100m freestyle     1            M   M
#         DEN Bronze                    sabre individual     3            M   M
#             Gold           heavyweight - two hand lift     1            M   M
#             Silver         heavyweight - one hand lift     2            M   M
#         FRA Bronze                     Sprint indivual     2            M   M
#             Gold                       foil individual     5            M   M
#             Silver                         triple jump     4            M   M
#         GBR Bronze                individual road race     2            M   M
#             Gold                               singles     2            M   M
#             Silver         heavyweight - two hand lift     3            M   M
#         GER Bronze                               vault     2            M   M
#             Gold                                 vault    26            M   M
#             Silver                               rings     5            M   M
#         GRE Bronze                         triple jump    22            M   M
#             Gold                      sabre individual    10            M   M
#             Silver                 team, parallel bars    20            M   M
#         HUN Bronze                             singles     3            M   M
#             Gold                       1200m freestyle     2            M   M
#             Silver                                800m     1            M   M
#         SUI Gold                          pommel horse     1            M   M
#             Silver                               vault     2            M   M
#         USA Bronze                           long jump     2            M   M
#             Gold                           triple jump    11            M   M
#             Silver                          pole vault     7            M   M
#         ZZX Bronze                             doubles     2            M   M
#             Gold                               doubles     2            M   M
#             Silver                             doubles     2            M   M
# ...                                                ...   ...          ...  ..
# 2008    SUI Gold                 individual time trial     3            M   M
#         SVK Bronze                          96 - 120kg     1            M   M
#             Gold                    K-1 (kayak single)     4            M   W
#             Silver                   trap (75 targets)     5            M   W
#         SWE Bronze                     Star - Keelboat     2            M   M
#             Silver               individual time trial     5            M   X
#         THA Gold                                  53kg     2            M   W
#             Silver                          60 - 64 kg     2            M   W
#         TJK Bronze             66 - 73kg (lightweight)     1            M   M
#             Silver                           74 - 84kg     1            M   M
#         TOG Bronze                  K-1 (kayak single)     1            M   M
#         TPE Bronze                                63kg     4            M   W
#         TRI Silver                        4x100m relay     5            M   M
#         TUN Gold                       1500m freestyle     1            M   M
#         TUR Bronze                           74 - 84kg     3            M   M
#             Gold                             60 - 66kg     1            M   M
#             Silver                               5000m     4            W   W
#         UKR Bronze  synchronized diving 3m springboard    16            M   W
#             Gold                            sabre team    10            M   W
#             Silver                           60 - 66kg     5            M   W
#         USA Bronze                   trap (75 targets)    81            M   X
#             Gold                            volleyball   125            M   X
#             Silver                          water polo   109            M   X
#         UZB Bronze                       parallel bars     3            M   W
#             Gold                            96 - 120kg     1            M   M
#             Silver                           66 - 74kg     2            M   M
#         VEN Bronze                             - 49 kg     1            W   W
#         VIE Silver        - 56kg, total (bantamweight)     1            M   M
#         ZIM Gold                       200m backstroke     1            W   W
#             Silver              400m individual medley     3            W   W
#
#
#                    count
# Edition NOC Medal
# 1896    AUS Gold       2
#         AUT Bronze     2
#             Gold       2
#             Silver     1
#         DEN Bronze     3
#             Gold       1
#             Silver     2
#         FRA Bronze     2
#             Gold       5
#             Silver     4
#         GBR Bronze     2
#             Gold       2
#             Silver     3
#         GER Bronze     2
#             Gold      26
#             Silver     5
#         GRE Bronze    22
#             Gold      10
#             Silver    20
#         HUN Bronze     3
#             Gold       2
#             Silver     1
#         SUI Gold       1
#             Silver     2
#         USA Bronze     2
#             Gold      11
#             Silver     7
#         ZZX Bronze     2
#             Gold       2
#             Silver     2
# ...                  ...
# 2008    SUI Gold       3
#         SVK Bronze     1
#             Gold       4
#             Silver     5
#         SWE Bronze     2
#             Silver     5
#         THA Gold       2
#             Silver     2
#         TJK Bronze     1
#             Silver     1
#         TOG Bronze     1
#         TPE Bronze     4
#         TRI Silver     5
#         TUN Gold       1
#         TUR Bronze     3
#             Gold       1
#             Silver     4
#         UKR Bronze    16
#             Gold      10
#             Silver     5
#         USA Bronze    81
#             Gold     125
#             Silver   109
#         UZB Bronze     3
#             Gold       1
#             Silver     2
#         VEN Bronze     1
#         VIE Silver     1
#         ZIM Gold       1
#             Silver     3
#
# [2356 rows x 24 columns]

# %%
df.groupby('Edition').agg(['min','max','count'])
# Out:
#          index                                  Athlete                        \
#            min    max count                         min                   max
# Edition
# 1896         0    150   151            ANDREOU, Joannis         ZUTTER, Louis
# 1900       151    662   512                AABYE, Edgar            ÖSTMO, Ole
# 1904       663   1132   470                ABELL, Louis        ZIRKEL, Albert
# 1908      1133   1936   804               ADAM, John M.        ZÜRNER, Albert
# 1912      1937   2821   885        AAS, Thomas Valentin       ÖSTENSEN, Östen
# 1920      2822   4119  1298       AALTONEN, Arvo Ossian  ÖSTERVOLD, Ole Olsen
# 1924      4120   5003   884               ABEGGLEN, Max        ZWERINA, Anton
# 1928      5004   5713   710         AGSTERIBBE, Estella        ZUMELZU, A. B.
# 1932      5714   6328   615       ABLOWICH, Edgar Allen         ZOMBORI, Ödön
# 1936      6329   7203   875          ABAY-NEMES, Oszkar         ZOMBORI, Ödön
# 1948      7204   8017   814    AALTONEN, Paavo Johannes  ZUDDAS, Gianbattista
# 1952      8018   8906   889    AALTONEN, Paavo Johannes     ÖSTRAND, Per-Olof
# 1956      8907   9791   885                ABDUL, Hamid        ZYBINA, Galina
# 1960      9792  10673   882                ABDUL, Hamid      ZÄHRINGER, Klaus
# 1964     10674  11683  1010                ABDUL, Hamid        ZYBINA, Galina
# 1968     11684  12714  1031           ABDUL, Rashid III        ZUCHOLD, Erika
# 1972     12715  13899  1185           ABDUL, Rashid III        ZUCHOLD, Erika
# 1976     13900  15204  1305           ABDUL, Rashid III   ZVYAGINTSEV, Viktor
# 1980     15205  16591  1387   ABASCAL GARCIA, Alejandro   ÖRSTED, Hans-Henrik
# 1984     16592  18050  1459  ABASCAL GOMEZ, Jose Manuel        ZSCHERPE, Iris
# 1988     18051  19596  1546       AARDENBURG, Willemien        ZÜLOW, Andreas
# 1992     19597  21301  1705                 ABAY, Peter   ZWOLLE, Hendrik Jan
# 1996     21302  23160  1859           AARDEWIJN, Pepijn   ZWOLLE, Hendrik Jan
# 2000     23161  25175  2015       ABANDA ETONG, Patrice        ZYKINA, Olesya
# 2004     25176  27173  1998               ABAS, Stephen        ZYKINA, Olesya
# 2008     27174  29215  2042            AAMODT, Ragnhild       ZVONAREVA, Vera
#
#                                 City                                  Sport  \
#         count                    min                    max count       min
# Edition
# 1896      151                 Athens                 Athens   151  Aquatics
# 1900      512                  Paris                  Paris   512  Aquatics
# 1904      470               St Louis               St Louis   470  Aquatics
# 1908      804                 London                 London   804  Aquatics
# 1912      885              Stockholm              Stockholm   885  Aquatics
# 1920     1298                Antwerp                Antwerp  1298  Aquatics
# 1924      884                  Paris                  Paris   884  Aquatics
# 1928      710              Amsterdam              Amsterdam   710  Aquatics
# 1932      615            Los Angeles            Los Angeles   615  Aquatics
# 1936      875                 Berlin                 Berlin   875  Aquatics
# 1948      814                 London                 London   814  Aquatics
# 1952      889               Helsinki               Helsinki   889  Aquatics
# 1956      885  Melbourne / Stockholm  Melbourne / Stockholm   885  Aquatics
# 1960      882                   Rome                   Rome   882  Aquatics
# 1964     1010                  Tokyo                  Tokyo  1010  Aquatics
# 1968     1031                 Mexico                 Mexico  1031  Aquatics
# 1972     1185                 Munich                 Munich  1185  Aquatics
# 1976     1305               Montreal               Montreal  1305  Aquatics
# 1980     1387                 Moscow                 Moscow  1387  Aquatics
# 1984     1459            Los Angeles            Los Angeles  1459  Aquatics
# 1988     1546                  Seoul                  Seoul  1546  Aquatics
# 1992     1705              Barcelona              Barcelona  1705  Aquatics
# 1996     1859                Atlanta                Atlanta  1859  Aquatics
# 2000     2015                 Sydney                 Sydney  2015  Aquatics
# 2004     1998                 Athens                 Athens  1998  Aquatics
# 2008     2042                Beijing                Beijing  2042  Aquatics
#
#          ...  Gender                               Event                   \
#          ...   count                                 min              max
# Edition  ...
# 1896     ...     151                               100km            vault
# 1900     ...     512                              0.5-1t    épée, masters
# 1904     ...     470             + 71.67kg (heavyweight)  épée individual
# 1908     ...     804             + 71.67kg (heavyweight)        épée team
# 1912     ...     885        + 82.5kg (super heavyweight)        épée team
# 1920     ...    1298             + 79.38kg (heavyweight)        épée team
# 1924     ...     884             + 79.38kg (heavyweight)        épée team
# 1928     ...     710             + 79.38kg (heavyweight)  épée individual
# 1932     ...     615             + 79.38kg (heavyweight)        épée team
# 1936     ...     875             + 79.38kg (heavyweight)        épée team
# 1948     ...     814                + 80kg (heavyweight)        épée team
# 1952     ...     889                + 81kg (heavyweight)        épée team
# 1956     ...     885                + 81kg (heavyweight)        épée team
# 1960     ...     882                + 81kg (heavyweight)        épée team
# 1964     ...    1010                + 80kg (heavyweight)        épée team
# 1968     ...    1031                + 81kg (heavyweight)        épée team
# 1972     ...    1185         + 100kg (super heavyweight)        épée team
# 1976     ...    1305         + 100kg (super heavyweight)        épée team
# 1980     ...    1387         + 100kg (super heavyweight)        épée team
# 1984     ...    1459         + 100kg (super heavyweight)        épée team
# 1988     ...    1546  + 110kg, total (super heavyweight)        épée team
# 1992     ...    1705  + 110kg, total (super heavyweight)        épée team
# 1996     ...    1859               + 100kg (heavyweight)        épée team
# 2000     ...    2015               + 100kg (heavyweight)        épée team
# 2004     ...    1998               + 100kg (heavyweight)        épée team
# 2008     ...    2042               + 100kg (heavyweight)        épée team
#
#               Event_gender             Medal
#         count          min max count     min     max count
# Edition
# 1896      151            M   M   151  Bronze  Silver   151
# 1900      512            M   X   512  Bronze  Silver   512
# 1904      470            M   W   470  Bronze  Silver   470
# 1908      804            M   X   804  Bronze  Silver   804
# 1912      885            M   X   885  Bronze  Silver   885
# 1920     1298            M   X  1298  Bronze  Silver  1298
# 1924      884            M   X   884  Bronze  Silver   884
# 1928      710            M   X   710  Bronze  Silver   710
# 1932      615            M   X   615  Bronze  Silver   615
# 1936      875            M   X   875  Bronze  Silver   875
# 1948      814            M   X   814  Bronze  Silver   814
# 1952      889            M   X   889  Bronze  Silver   889
# 1956      885            M   X   885  Bronze  Silver   885
# 1960      882            M   X   882  Bronze  Silver   882
# 1964     1010            M   X  1010  Bronze  Silver  1010
# 1968     1031            M   X  1031  Bronze  Silver  1031
# 1972     1185            M   X  1185  Bronze  Silver  1185
# 1976     1305            M   X  1305  Bronze  Silver  1305
# 1980     1387            M   X  1387  Bronze  Silver  1387
# 1984     1459            M   X  1459  Bronze  Silver  1459
# 1988     1546            M   X  1546  Bronze  Silver  1546
# 1992     1705            M   X  1705  Bronze  Silver  1705
# 1996     1859            M   X  1859  Bronze  Silver  1859
# 2000     2015            M   X  2015  Bronze  Silver  2015
# 2004     1998            M   X  1998  Bronze  Silver  1998
# 2008     2042            M   X  2042  Bronze  Silver  2042
#
# [26 rows x 30 columns]

# %%
df.groupby(['Edition','NOC','Medal']).agg({'Edition':['min','max','count']})
# Out:
#                    Edition
#                        min   max count
# Edition NOC Medal
# 1896    AUS Gold      1896  1896     2
#         AUT Bronze    1896  1896     2
#             Gold      1896  1896     2
#             Silver    1896  1896     1
#         DEN Bronze    1896  1896     3
#             Gold      1896  1896     1
#             Silver    1896  1896     2
#         FRA Bronze    1896  1896     2
#             Gold      1896  1896     5
#             Silver    1896  1896     4
#         GBR Bronze    1896  1896     2
#             Gold      1896  1896     2
#             Silver    1896  1896     3
#         GER Bronze    1896  1896     2
#             Gold      1896  1896    26
#             Silver    1896  1896     5
#         GRE Bronze    1896  1896    22
#             Gold      1896  1896    10
#             Silver    1896  1896    20
#         HUN Bronze    1896  1896     3
#             Gold      1896  1896     2
#             Silver    1896  1896     1
#         SUI Gold      1896  1896     1
#             Silver    1896  1896     2
#         USA Bronze    1896  1896     2
#             Gold      1896  1896    11
#             Silver    1896  1896     7
#         ZZX Bronze    1896  1896     2
#             Gold      1896  1896     2
#             Silver    1896  1896     2
# ...                    ...   ...   ...
# 2008    SUI Gold      2008  2008     3
#         SVK Bronze    2008  2008     1
#             Gold      2008  2008     4
#             Silver    2008  2008     5
#         SWE Bronze    2008  2008     2
#             Silver    2008  2008     5
#         THA Gold      2008  2008     2
#             Silver    2008  2008     2
#         TJK Bronze    2008  2008     1
#             Silver    2008  2008     1
#         TOG Bronze    2008  2008     1
#         TPE Bronze    2008  2008     4
#         TRI Silver    2008  2008     5
#         TUN Gold      2008  2008     1
#         TUR Bronze    2008  2008     3
#             Gold      2008  2008     1
#             Silver    2008  2008     4
#         UKR Bronze    2008  2008    16
#             Gold      2008  2008    10
#             Silver    2008  2008     5
#         USA Bronze    2008  2008    81
#             Gold      2008  2008   125
#             Silver    2008  2008   109
#         UZB Bronze    2008  2008     3
#             Gold      2008  2008     1
#             Silver    2008  2008     2
#         VEN Bronze    2008  2008     1
#         VIE Silver    2008  2008     1
#         ZIM Gold      2008  2008     1
#             Silver    2008  2008     3
#
# [2356 rows x 3 columns]

# %%
df.loc[df.Athlete=='LEWIS, Carl'].groupby('Athlete').agg({'Edition':['min','max','count']})
# Out:
#             Edition
#                 min   max count
# Athlete
# LEWIS, Carl    1984  1996    10

# %%
#Total number of medals won by each country
# %matplotlib inline
df.groupby('Edition').size().plot()

# %%
df=pd.read_csv("olympics.csv" ,skiprows=4)#Observations start from row 5 in the original csv file
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df.groupby('NOC').agg({"Edition":['count','min','max']})
# Out:
#     Edition
#       count   min   max
# NOC
# AFG       1  2008  2008
# AHO       1  1988  1988
# ALG      14  1984  2008
# ANZ      29  1908  1912
# ARG     239  1924  2008
# ARM       9  1996  2008
# AUS    1075  1896  2008
# AUT     146  1896  2008
# AZE      16  1996  2008
# BAH      23  1956  2008
# BAR       1  2000  2000
# BDI       1  1996  1996
# BEL     408  1900  2008
# BER       1  1976  1976
# BLR      92  1996  2008
# BOH       7  1900  1908
# BRA     372  1920  2008
# BUL     331  1952  2008
# BWI       5  1960  1960
# CAN     592  1900  2008
# CHI      33  1928  2008
# CHN     679  1984  2008
# CIV       1  1984  1984
# CMR      22  1968  2008
# COL      11  1972  2008
# CRC       4  1988  2000
# CRO      79  1992  2008
# CUB     395  1900  2008
# CZE      41  1996  2008
# DEN     491  1896  2008
# ..      ...   ...   ...
# SRI       2  1948  2000
# SUD       1  2008  2008
# SUI     376  1896  2008
# SUR       2  1988  1992
# SVK      29  1996  2008
# SWE    1021  1900  2008
# SYR       3  1984  2004
# TAN       2  1980  1980
# TCH     329  1920  1992
# TGA       1  1996  1996
# THA      21  1976  2008
# TJK       2  2008  2008
# TOG       1  2008  2008
# TPE      42  1960  2008
# TRI      20  1948  2008
# TUN       7  1964  2008
# TUR      82  1936  2008
# UAE       1  2004  2004
# UGA       6  1968  1996
# UKR     148  1996  2008
# URS    2049  1952  1988
# URU      76  1924  2000
# USA    4335  1896  2008
# UZB      17  1996  2008
# VEN      11  1952  2008
# VIE       2  2000  2008
# YUG     435  1924  2000
# ZAM       2  1984  1996
# ZIM      23  1980  2008
# ZZX      48  1896  1904
#
# [138 rows x 3 columns]

# %% [markdown]
# <h3>Reshaping:</h3>Stack and unstack functions.The stack function allows you to move the inner columns to the rows for the dataframe and the unstack function does the reverse.

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
bei=df[(df.Edition==2008)&((df.Event=='100m')|(df.Event=='200m'))]

# %%
mw=bei.groupby(['NOC','Gender','Event','Discipline']).size()
mw
# Out:
# NOC  Gender  Event  Discipline
# JAM  Men     100m   Athletics     1
#              200m   Athletics     1
#      Women   100m   Athletics     3
#              200m   Athletics     2
# TRI  Men     100m   Athletics     1
# USA  Men     100m   Athletics     1
#              200m   Athletics     2
#      Women   200m   Athletics     1
# dtype: int64

# %%
k=mw.unstack(['Discipline','Event'])

# %%
k.stack()
# Out:
# Discipline        Athletics
# NOC Gender Event
# JAM Men    100m         1.0
#            200m         1.0
#     Women  100m         3.0
#            200m         2.0
# TRI Men    100m         1.0
# USA Men    100m         1.0
#            200m         2.0
#     Women  200m         1.0

# %%
k.stack('Discipline')
# Out:
# Event                  100m  200m
# NOC Gender Discipline
# JAM Men    Athletics    1.0   1.0
#     Women  Athletics    3.0   2.0
# TRI Men    Athletics    1.0   NaN
# USA Men    Athletics    1.0   2.0
#     Women  Athletics    NaN   1.0

# %%
k.unstack()
# Out:
# Discipline Athletics
# Event           100m       200m
# Gender           Men Women  Men Women
# NOC
# JAM              1.0   3.0  1.0   2.0
# TRI              1.0   NaN  NaN   NaN
# USA              1.0   NaN  2.0   1.0

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
gol=df[(df.NOC=='USA')&(df.Medal=='Gold')]
gol.groupby(['Edition','Gender']).size().unstack('Gender',fill_value=0).plot()#fill_value =0 is to change the NAN into 0

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
fin=df.groupby(['Athlete','Medal']).size().unstack('Medal',fill_value=0)
fin.sort_values(['Gold','Silver','Bronze'],ascending=False)[:5][['Gold','Silver','Bronze']].plot(kind='bar')

# %%
import seaborn as sns
lo=df[df.Edition==2008]
hm=lo.groupby(['NOC','Medal']).size().unstack('Medal',fill_value=0)

# %%
shm=hm.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']]

# %%
sns.heatmap(shm)

# %%
shm=shm.transpose()
shm
# Out:
# NOC     USA  CHN  RUS  GER  KOR  NED  AUS  GBR  FRA  JPN ...   VIE  ARM  TPE  \
# Medal                                                    ...
# Gold    125   74   43   42   41   40   31   31   25   23 ...     0    0    0
# Silver  109   53   44   16   11   18   42   25   23   11 ...     1    0    0
# Bronze   81   57   56   43   26    4   76   21   28   17 ...     0    6    4
#
# NOC     AFG  EGY  ISR  MDA  MRI  TOG  VEN
# Medal
# Gold      0    0    0    0    0    0    0
# Silver    0    0    0    0    0    0    0
# Bronze    1    1    1    1    1    1    1
#
# [3 rows x 86 columns]

# %%
plt.figure(figsize=(20,5))
sns.heatmap(shm)

# %%
fin=df.groupby(['Athlete','Medal']).size().unstack('Medal',fill_value=0)
fin.sort_values(['Gold','Silver','Bronze'],ascending=False)[:5][['Gold','Silver','Bronze']].plot(kind='bar')

# %%
#Creating own colormaps

from matplotlib.colors import ListedColormap

# %%
sns.color_palette()
# Out:
# [(0.29803921568627451, 0.44705882352941179, 0.69019607843137254),
#  (0.33333333333333331, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.30588235294117649, 0.32156862745098042),
#  (0.50588235294117645, 0.44705882352941179, 0.69803921568627447),
#  (0.80000000000000004, 0.72549019607843135, 0.45490196078431372),
#  (0.39215686274509803, 0.70980392156862748, 0.80392156862745101)]

# %%
sns.palplot(sns.color_palette())

# %%
gsb=['#dbb40c','#c5c9c7','#a87900']

# %%
sns.palplot(gsb)

# %%
mycolor=ListedColormap(sns.color_palette(gsb))

# %%
fin=df.groupby(['Athlete','Medal']).size().unstack('Medal',fill_value=0)
fin.sort_values(['Gold','Silver','Bronze'],ascending=False)[:5][['Gold','Silver','Bronze']].plot(kind='bar',colormap=mycolor)

# %% [markdown]
# <h3> In every Olympics, which US athlete has won the most total number of medals?
# <br>Include the athletes discipline in your solution </h3>

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
fin=df[df.NOC=='USA']
fin
# Out:
#           City  Edition       Sport       Discipline  \
# 11      Athens     1896   Athletics        Athletics
# 13      Athens     1896   Athletics        Athletics
# 15      Athens     1896   Athletics        Athletics
# 19      Athens     1896   Athletics        Athletics
# 21      Athens     1896   Athletics        Athletics
# 22      Athens     1896   Athletics        Athletics
# 27      Athens     1896   Athletics        Athletics
# 29      Athens     1896   Athletics        Athletics
# 30      Athens     1896   Athletics        Athletics
# 31      Athens     1896   Athletics        Athletics
# 32      Athens     1896   Athletics        Athletics
# 33      Athens     1896   Athletics        Athletics
# 34      Athens     1896   Athletics        Athletics
# 40      Athens     1896   Athletics        Athletics
# 41      Athens     1896   Athletics        Athletics
# 43      Athens     1896   Athletics        Athletics
# 46      Athens     1896   Athletics        Athletics
# 118     Athens     1896    Shooting         Shooting
# 119     Athens     1896    Shooting         Shooting
# 124     Athens     1896    Shooting         Shooting
# 231      Paris     1900   Athletics        Athletics
# 232      Paris     1900   Athletics        Athletics
# 233      Paris     1900   Athletics        Athletics
# 234      Paris     1900   Athletics        Athletics
# 235      Paris     1900   Athletics        Athletics
# 236      Paris     1900   Athletics        Athletics
# 240      Paris     1900   Athletics        Athletics
# 242      Paris     1900   Athletics        Athletics
# 243      Paris     1900   Athletics        Athletics
# 252      Paris     1900   Athletics        Athletics
# ...        ...      ...         ...              ...
# 29019  Beijing     2008  Volleyball    Beach volley.
# 29024  Beijing     2008  Volleyball    Beach volley.
# 29025  Beijing     2008  Volleyball    Beach volley.
# 29040  Beijing     2008  Volleyball       Volleyball
# 29041  Beijing     2008  Volleyball       Volleyball
# 29042  Beijing     2008  Volleyball       Volleyball
# 29043  Beijing     2008  Volleyball       Volleyball
# 29044  Beijing     2008  Volleyball       Volleyball
# 29045  Beijing     2008  Volleyball       Volleyball
# 29046  Beijing     2008  Volleyball       Volleyball
# 29047  Beijing     2008  Volleyball       Volleyball
# 29048  Beijing     2008  Volleyball       Volleyball
# 29049  Beijing     2008  Volleyball       Volleyball
# 29050  Beijing     2008  Volleyball       Volleyball
# 29051  Beijing     2008  Volleyball       Volleyball
# 29088  Beijing     2008  Volleyball       Volleyball
# 29089  Beijing     2008  Volleyball       Volleyball
# 29090  Beijing     2008  Volleyball       Volleyball
# 29091  Beijing     2008  Volleyball       Volleyball
# 29092  Beijing     2008  Volleyball       Volleyball
# 29093  Beijing     2008  Volleyball       Volleyball
# 29094  Beijing     2008  Volleyball       Volleyball
# 29095  Beijing     2008  Volleyball       Volleyball
# 29096  Beijing     2008  Volleyball       Volleyball
# 29097  Beijing     2008  Volleyball       Volleyball
# 29098  Beijing     2008  Volleyball       Volleyball
# 29099  Beijing     2008  Volleyball       Volleyball
# 29151  Beijing     2008   Wrestling  Wrestling Free.
# 29161  Beijing     2008   Wrestling  Wrestling Free.
# 29209  Beijing     2008   Wrestling  Wrestling Gre-R
#
#                          Athlete  NOC Gender                  Event  \
# 11                 LANE, Francis  USA    Men                   100m
# 13                 BURKE, Thomas  USA    Men                   100m
# 15                CURTIS, Thomas  USA    Men           110m hurdles
# 19                 BLAKE, Arthur  USA    Men                  1500m
# 21                 BURKE, Thomas  USA    Men                   400m
# 22              JAMISON, Herbert  USA    Men                   400m
# 27               GARRETT, Robert  USA    Men           discus throw
# 29                 CLARK, Ellery  USA    Men              high jump
# 30               CONNOLLY, James  USA    Men              high jump
# 31               GARRETT, Robert  USA    Men              high jump
# 32               CONNOLLY, James  USA    Men              long jump
# 33                 CLARK, Ellery  USA    Men              long jump
# 34               GARRETT, Robert  USA    Men              long jump
# 40          HOYT, William Welles  USA    Men             pole vault
# 41                 TYLER, Albert  USA    Men             pole vault
# 43               GARRETT, Robert  USA    Men               shot put
# 46               CONNOLLY, James  USA    Men            triple jump
# 118                  PAINE, John  USA    Men        25m army pistol
# 119                PAINE, Sumner  USA    Men        25m army pistol
# 124                PAINE, Sumner  USA    Men  50m pistol (60 shots)
# 231              JARVIS, Francis  USA    Men                   100m
# 232    TEWKSBURY, Walter B. John  USA    Men                   100m
# 233           MOLONEY, Frederick  USA    Men           110m hurdles
# 234            KRAENZLEIN, Alvin  USA    Men           110m hurdles
# 235                 MCLEAN, John  USA    Men           110m hurdles
# 236                   BRAY, John  USA    Men                  1500m
# 240    TEWKSBURY, Walter B. John  USA    Men                   200m
# 242    TEWKSBURY, Walter B. John  USA    Men           200m hurdles
# 243            KRAENZLEIN, Alvin  USA    Men           200m hurdles
# 252        LONG, Maxwell W.Maxey  USA    Men                   400m
# ...                          ...  ...    ...                    ...
# 29019               ROGERS, Todd  USA    Men       beach volleyball
# 29024         MAY-TREANOR, Misty  USA  Women       beach volleyball
# 29025               WALSH, Kerri  USA  Women       beach volleyball
# 29040                 BALL, Lloy  USA    Men             volleyball
# 29041           GARDNER, Gabriel  USA    Men             volleyball
# 29042              HANSEN, Kevin  USA    Men             volleyball
# 29043               HOFF, Thomas  USA    Men             volleyball
# 29044         LAMBOURNE, Richard  USA    Men             volleyball
# 29045                 LEE, David  USA    Men             volleyball
# 29046               MILLAR, Ryan  USA    Men             volleyball
# 29047            PRIDDY, William  USA    Men             volleyball
# 29048               ROONEY, Sean  USA    Men             volleyball
# 29049              SALMON, Riley  USA    Men             volleyball
# 29050           STANLEY, Clayton  USA    Men             volleyball
# 29051           TOUZINSKY, Scott  USA    Men             volleyball
# 29088       AH MOW-SANTOS, Robyn  USA  Women             volleyball
# 29089              BERG, Lindsey  USA  Women             volleyball
# 29090              BOWN, Heather  USA  Women             volleyball
# 29091              DAVIS, Nicole  USA  Women             volleyball
# 29092            GLASS, Kimberly  USA  Women             volleyball
# 29093       HANEEF-PARK, Tayyiba  USA  Women             volleyball
# 29094           JOINES, Jennifer  USA  Women             volleyball
# 29095            NNAMANI, Ogonna  USA  Women             volleyball
# 29096     SCOTT-ARRUDA, Danielle  USA  Women             volleyball
# 29097              SYKORA, Stacy  USA  Women             volleyball
# 29098                 TOM, Logan  USA  Women             volleyball
# 29099            WILLOUGHBY, Kim  USA  Women             volleyball
# 29151              CEJUDO, Henry  USA    Men                 - 55kg
# 29161              MILLER, Randi  USA  Women              55 - 63kg
# 29209              WHEELER, Adam  USA    Men              84 - 96kg
#
#       Event_gender   Medal
# 11               M  Bronze
# 13               M    Gold
# 15               M    Gold
# 19               M  Silver
# 21               M    Gold
# 22               M  Silver
# 27               M    Gold
# 29               M    Gold
# 30               M  Silver
# 31               M  Silver
# 32               M  Bronze
# 33               M    Gold
# 34               M  Silver
# 40               M    Gold
# 41               M  Silver
# 43               M    Gold
# 46               M    Gold
# 118              M    Gold
# 119              M  Silver
# 124              M    Gold
# 231              M    Gold
# 232              M  Silver
# 233              M  Bronze
# 234              M    Gold
# 235              M  Silver
# 236              M  Bronze
# 240              M    Gold
# 242              M  Bronze
# 243              M    Gold
# 252              M    Gold
# ...            ...     ...
# 29019            M    Gold
# 29024            W    Gold
# 29025            W    Gold
# 29040            M    Gold
# 29041            M    Gold
# 29042            M    Gold
# 29043            M    Gold
# 29044            M    Gold
# 29045            M    Gold
# 29046            M    Gold
# 29047            M    Gold
# 29048            M    Gold
# 29049            M    Gold
# 29050            M    Gold
# 29051            M    Gold
# 29088            W  Silver
# 29089            W  Silver
# 29090            W  Silver
# 29091            W  Silver
# 29092            W  Silver
# 29093            W  Silver
# 29094            W  Silver
# 29095            W  Silver
# 29096            W  Silver
# 29097            W  Silver
# 29098            W  Silver
# 29099            W  Silver
# 29151            M    Gold
# 29161            W  Bronze
# 29209            M  Bronze
#
# [4335 rows x 10 columns]

# %%
usath=fin.groupby(['Edition','Athlete','Medal','Discipline']).size().unstack('Medal',fill_value=0)
usath["tot"]=usath['Gold']+usath['Silver']+usath['Bronze']
usath.reset_index(inplace=True)
usath.head()
# Out:
# Medal  Edition          Athlete Discipline  Bronze  Gold  Silver  tot
# 0         1896    BLAKE, Arthur  Athletics       0     0       1    1
# 1         1896    BURKE, Thomas  Athletics       0     2       0    2
# 2         1896    CLARK, Ellery  Athletics       0     2       0    2
# 3         1896  CONNOLLY, James  Athletics       1     1       1    3
# 4         1896   CURTIS, Thomas  Athletics       0     1       0    1

# %%
ls=[group.sort_values('tot',ascending=False)[:1] for year,group in usath.groupby('Edition')]
top=pd.DataFrame()
for i in ls:
    top=top.append(i)
top
# Out:
# Medal  Edition                      Athlete   Discipline  Bronze  Gold  \
# 5         1896              GARRETT, Robert    Athletics       0     2
# 14        1900               BAXTER, Irving    Athletics       0     2
# 117       1904                EYSER, George  Artistic G.       1     3
# 370       1908             SHERIDAN, Martin    Athletics       1     2
# 428       1912        OSBURN, Carl Townsend     Shooting       1     1
# 567       1920       SPOONER, Lloyd Spencer     Shooting       2     4
# 705       1924            RICHARDS, Vincent       Tennis       0     2
# 811       1928       OSIPOWICH, Albina Lucy     Swimming       0     2
# 871       1932           DIDRIKSON, Mildred    Athletics       0     2
# 1040      1936                 OWENS, Jesse    Athletics       0     4
# 1142      1948      MCLANE, James Price Jr.     Swimming       0     2
# 1249      1952          KONNO, Ford Hiroshi     Swimming       0     2
# 1394      1956        MORROW, Robert Joseph    Athletics       0     3
# 1515      1960  VON SALTZA, Susan Christina     Swimming       0     3
# 1634      1964        STOUDER, Sharon Marie     Swimming       0     3
# 1688      1968    HICKCOX, Charles Buchanan     Swimming       0     3
# 1859      1972                  SPITZ, Mark     Swimming       0     7
# 1885      1976    BABASHOFF, Shirley Farber     Swimming       0     1
# 2222      1984             RETTON, Mary-Lou  Artistic G.       2     1
# 2309      1988              BIONDI, Matthew     Swimming       1     5
# 2582      1992              MILLER, Shannon  Artistic G.       3     0
# 2718      1996               HALL, Gary Jr.     Swimming       0     2
# 3060      2000                 TORRES, Dara     Swimming       3     2
# 3241      2004              PHELPS, Michael     Swimming       2     6
# 3478      2008              PHELPS, Michael     Swimming       0     8
#
# Medal  Silver  tot
# 5           2    4
# 14          3    5
# 117         2    6
# 370         0    3
# 428         2    4
# 567         1    7
# 705         1    3
# 811         0    2
# 871         1    3
# 1040        0    4
# 1142        1    3
# 1249        1    3
# 1394        0    3
# 1515        1    4
# 1634        1    4
# 1688        1    4
# 1859        0    7
# 1885        4    5
# 2222        2    5
# 2309        1    7
# 2582        2    5
# 2718        2    4
# 3060        0    5
# 3241        0    8
# 3478        0    8
